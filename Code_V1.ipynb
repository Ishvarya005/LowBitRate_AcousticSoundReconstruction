# %% [markdown]
# # Step 0: Import Dataset and check the files in each folder

# %%
import os

DATASETS_PATH = "/kaggle/input"

print("📂 Available datasets in /kaggle/input:")
print(os.listdir(DATASETS_PATH))

# %%
DATA_PATH = "/kaggle/input/musan-data/musan"  # Adjust if needed

if os.path.exists(DATA_PATH):
    print("✅ Dataset found! Listing contents:")
    print(os.listdir(DATA_PATH))
else:
    print("❌ Dataset not found! Double-check the path.")

# %%
for category in ["music", "noise", "speech"]:
    folder_path = os.path.join(DATA_PATH, category)
    if os.path.exists(folder_path):
        files = os.listdir(folder_path)[:5]  # Show first 5 files
        print(f"\n📂 {category} - {len(os.listdir(folder_path))} files")
        print(files)
    else:
        print(f"⚠️ Folder '{category}' not found!")

# %%
for category in ["music", "noise", "speech"]:
    folder_path = os.path.join(DATA_PATH, category)

    for subfolder in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder)
        
        if os.path.isdir(subfolder_path):  # Ensure it's a directory
            audio_files = [f for f in os.listdir(subfolder_path) if f.endswith(('.wav', '.mp3'))][:5]
            print(f"\n📂 {category}/{subfolder} - {len(os.listdir(subfolder_path))} files")
            print(audio_files)

# %% [markdown]
# # Step 1: Preprocessing: Checking all files to know its sample rates and channel

# %%
import os
import librosa

DATA_PATH = "/kaggle/input/musan-data/musan/"  # Update this with your actual dataset path

# Function to check sample rate & channels
def check_audio_properties(root_folder):
    sample_rates = {}
    channel_counts = {}

    for root, _, files in os.walk(root_folder):
        for file in files:
            if file.endswith(".wav"):  # Only process WAV files
                file_path = os.path.join(root, file)
                
                try:
                    audio, sr = librosa.load(file_path, sr=None, mono=False)  # Load in original format
                    channels = 1 if len(audio.shape) == 1 else 2  # Determine mono or stereo

                    # Store results
                    if sr not in sample_rates:
                        sample_rates[sr] = 0
                    sample_rates[sr] += 1

                    if channels not in channel_counts:
                        channel_counts[channels] = 0
                    channel_counts[channels] += 1

                except Exception as e:
                    print(f"Error processing {file_path}: {e}")

    return sample_rates, channel_counts

# Run check
sample_rates, channel_counts = check_audio_properties(DATA_PATH)

# Print results
print("🎵 Sample Rate Distribution:", sample_rates)
print("🎧 Channel Distribution (1=Mono, 2=Stereo):", channel_counts)

# %%
import os
import subprocess
import json
from collections import defaultdict

# Define dataset path
DATA_PATH = "/kaggle/input/musan-data/musan"
CATEGORIES = ["music", "noise", "speech"]
file_count = defaultdict(int)
MAX_FILES = 5  # Limit to 5 files per category

# Function to extract bit rate
def get_bit_rate(file_path):
    cmd = f"ffprobe -i '{file_path}' -show_entries stream=bit_rate -of json -v quiet"
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    
    try:
        data = json.loads(result.stdout)  # Convert JSON string to dictionary
        return data["streams"][0]["bit_rate"] if "streams" in data and data["streams"] else "N/A"
    except (json.JSONDecodeError, KeyError, IndexError):
        return "N/A"

# Process only 5 files from each category
for root, _, files in os.walk(DATA_PATH):
    for file in files:
        if file.endswith(".wav"):
            file_path = os.path.join(root, file)

            # Identify category from folder structure
            for category in CATEGORIES:
                if f"/{category}/" in file_path and file_count[category] < MAX_FILES:
                    bit_rate = get_bit_rate(file_path)
                    print(f"🔍 {category.upper()} | {file}: {bit_rate} bps")

                    file_count[category] += 1
                    break  # Move to next file

        if all(count >= MAX_FILES for count in file_count.values()):
            break

print("\n✅ Bit rate extraction complete for 5 files per category!")

# %% [markdown]
# ## Since all files have the same sample rate of 16kHz and all are mono, we dont have to perform the explicit standardization

# %% [markdown]
# ## Since all files show a high bit-rate of 256kbps, we compress to different low bit-rates

# %% [markdown]
# # Step 2: Compression at different bit rates for all files

# %%
# !apt-get install -y ffmpeg

# %%
import os
dataset_path = "/kaggle/input/compressed-sample1"
if os.path.exists(dataset_path):
    print("✅ Dataset exists! Contents:")
    print(os.listdir(dataset_path))
else:
    print("❌ Dataset not found. Check the dataset name.")

# %%
import os
import subprocess
import shutil

# Paths
DATA_PATH = "/kaggle/input/musan-data/musan/music"
OUTPUT_PATH = "/kaggle/working/compressed_music_sample"

# Bitrates for music compression
BITRATES = {"16kbps": "16000", "32kbps": "32000", "64kbps": "64000"}

# Ensure output directory exists
os.makedirs(OUTPUT_PATH, exist_ok=True)

# Get a subfolder inside 'music'
music_subfolders = [f.path for f in os.scandir(DATA_PATH) if f.is_dir()]
if not music_subfolders:
    print("❌ No subfolders found in music.")
else:
    music_folder = music_subfolders[0]  # Choose the first subfolder
    music_files = [f for f in os.listdir(music_folder) if f.endswith(".wav")][:5]  # Pick 5 files

    # Compress 5 files
    for file in music_files:
        input_file = os.path.join(music_folder, file)
        for bitrate_name, bitrate_value in BITRATES.items():
            output_dir = os.path.join(OUTPUT_PATH, f"compressed_{bitrate_name}")
            os.makedirs(output_dir, exist_ok=True)
            output_file = os.path.join(output_dir, file.replace(".wav", ".opus"))
            
            # Compress using ffmpeg
            cmd = f"ffmpeg -i '{input_file}' -c:a libopus -b:a {bitrate_value} '{output_file}' -y"
            subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    print("✅ Compression complete! Files saved in:", OUTPUT_PATH)

# %%
import shutil

# Path to save the zip file
ZIP_PATH = "/kaggle/working/compressed_music_sample.zip"

# Create zip archive
shutil.make_archive(ZIP_PATH.replace(".zip", ""), 'zip', "/kaggle/working/compressed_music_sample")

print(f"✅ Zip file created: {ZIP_PATH}")

# %% [markdown]
# # Step 3.1: Compressing the speech folder applying 3 bit rates corresponding to speech data

# %% [markdown]
# >### Here the compressing code is shown for speech data, similarly compression is been carried out for music files (5 subfolders - fma, fma-western-art, hd-classical, jamendo, rfm) by taking the first 100 files in each subfolder and for noise data too (by taking first 100 files from the 2 subfolders - free-sound and sound-bible)

# %%
import os
import subprocess
import shutil

# Paths
DATA_PATH = "/kaggle/input/musan-data/musan/speech"
OUTPUT_PATH = "/kaggle/working/compressed_speech"

# Bitrates for speech compression
BITRATES = {
    "3kbps": "3000",
    "6kbps": "6000",
    "12kbps": "12000"
}

# Create output directory if not exists
os.makedirs(OUTPUT_PATH, exist_ok=True)

# Function to compress a single file
def compress_audio(input_file, output_file, bitrate):
    cmd = f"ffmpeg -i '{input_file}' -c:a libopus -b:a {bitrate} '{output_file}' -y"
    subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Resume check: Load last processed file if exists
resume_file = "/kaggle/working/speech_last_processed.txt"
last_processed = None
if os.path.exists(resume_file):
    with open(resume_file, "r") as f:
        last_processed = f.read().strip()

# Process files
processed_count = 0
resume_found = last_processed is None  # If no resume file, start immediately

for root, _, files in os.walk(DATA_PATH):
    # Only process files in 'librivox' folder
    if 'librivox' in root:
        for file in sorted(files):  # Sorting ensures consistent processing order
            if file.endswith(".wav"):
                input_file = os.path.join(root, file)
                relative_path = os.path.relpath(root, DATA_PATH)  # Maintain hierarchy
                
                if not resume_found:
                    if input_file == last_processed:
                        resume_found = True  # Resume processing from the next file
                    continue
                
                # Apply compression for each bitrate
                for bitrate_label, bitrate_value in BITRATES.items():
                    output_dir = os.path.join(OUTPUT_PATH, f"compressed_{bitrate_label}", relative_path)
                    os.makedirs(output_dir, exist_ok=True)  # Create directories if missing
                    
                    output_file = os.path.join(output_dir, file.replace(".wav", ".opus"))
                    compress_audio(input_file, output_file, bitrate_value)

                processed_count += 1
                
                # Save progress every 50 files
                if processed_count % 50 == 0:
                    with open(resume_file, "w") as f:
                        f.write(input_file)
                    
                    # Zip and upload files every 50 processed
                    zip_path = "/kaggle/working/compressed_speech.zip"
                    shutil.make_archive(zip_path.replace(".zip", ""), 'zip', OUTPUT_PATH)
                    print("✅ 50 files compressed & backup saved!")

print("✅ Speech compression complete!")

# Final dataset backup
final_zip_path = "/kaggle/working/compressed_speech_final.zip"
shutil.make_archive(final_zip_path.replace(".zip", ""), 'zip', OUTPUT_PATH)
print(f"✅ Final backup saved at: {final_zip_path}")
# Out:
# ✅ 50 files compressed & backup saved!
# ✅ 50 files compressed & backup saved!
# ✅ 50 files compressed & backup saved!
# ✅ Speech compression complete!
# ✅ Final backup saved at: /kaggle/working/compressed_speech_final.zip

# %% [markdown]
# # Step 3.2: Compressing speech subfolder : us-gov

# %%
import os
import subprocess
import shutil

# Paths
DATA_PATH = "/kaggle/input/musan-data/musan/speech/us-gov"
OUTPUT_PATH = "/kaggle/working/usgov_compressed_speech"

# Bitrates for speech compression
BITRATES = {
    "3kbps": "3000",
    "6kbps": "6000",
    "12kbps": "12000"
}

# Create output directory if not exists
os.makedirs(OUTPUT_PATH, exist_ok=True)

# Function to compress a single file
def compress_audio(input_file, output_file, bitrate):
    cmd = f"ffmpeg -i '{input_file}' -c:a libopus -b:a {bitrate} '{output_file}' -y"
    subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Resume check: Load last processed file if exists
resume_file = "/kaggle/working/usgov_last_processed.txt"
last_processed = None
if os.path.exists(resume_file):
    with open(resume_file, "r") as f:
        last_processed = f.read().strip()

# Process files
processed_count = 0
resume_found = last_processed is None  # If no resume file, start immediately

for root, _, files in os.walk(DATA_PATH):
    for file in sorted(files):  # Sorting ensures consistent processing order
        if file.endswith(".wav"):
            input_file = os.path.join(root, file)
            relative_path = os.path.relpath(root, DATA_PATH)  # Maintain hierarchy

            if not resume_found:
                if input_file == last_processed:
                    resume_found = True  # Resume processing from the next file
                continue

            # Apply compression for each bitrate
            for bitrate_label, bitrate_value in BITRATES.items():
                output_dir = os.path.join(OUTPUT_PATH, f"usgov_compressed_{bitrate_label}", relative_path)
                os.makedirs(output_dir, exist_ok=True)  # Create directories if missing

                output_file = os.path.join(output_dir, file.replace(".wav", ".opus"))
                compress_audio(input_file, output_file, bitrate_value)

            processed_count += 1

            # Stop after compressing 150 files
            if processed_count >= 150:
                break

            # Save progress every 50 files
            if processed_count % 50 == 0:
                with open(resume_file, "w") as f:
                    f.write(input_file)
                
                # Zip and upload files every 50 processed
                zip_path = "/kaggle/working/usgov_compressed_speech.zip"
                shutil.make_archive(zip_path.replace(".zip", ""), 'zip', OUTPUT_PATH)
                print("✅ 50 files compressed & backup saved!")

print("✅ US-GOV speech compression complete!")

# Final dataset backup
final_zip_path = "/kaggle/working/usgov_compressed_speech_final.zip"
shutil.make_archive(final_zip_path.replace(".zip", ""), 'zip', OUTPUT_PATH)
print(f"✅ Final backup saved at: {final_zip_path}")
# Out:
# ✅ 50 files compressed & backup saved!
# ✅ 50 files compressed & backup saved!
# ✅ US-GOV speech compression complete!
# ✅ Final backup saved at: /kaggle/working/usgov_compressed_speech_final.zip

# %% [markdown]
# # Step 4: Analyzing the speech signal quality before and after compression using SNR

# %%
pip install pystoi
# Out:
# Collecting pystoi
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.13.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->pystoi) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->pystoi) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->pystoi) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->pystoi) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->pystoi) (2024.2.0)
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Installing collected packages: pystoi
# Successfully installed pystoi-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
#analyzing using SNR,SDR,STOI and PESQ for librivox data of 3kbps

import os
import librosa
import numpy as np
from pesq import pesq
from pystoi import stoi
from mir_eval.separation import bss_eval_sources

# === Constants ===
SAMPLE_RATE = 16000
DURATION = 30
TARGET_SAMPLES = SAMPLE_RATE * DURATION

# === Evaluation Functions ===
def fix_length(audio, target_len):
    if len(audio) > target_len:
        return audio[:target_len]
    return np.pad(audio, (0, target_len - len(audio)))

def snr(original, compressed):
    min_len = min(len(original), len(compressed))
    original = original[:min_len]
    compressed = compressed[:min_len]
    noise = original - compressed
    eps = 1e-10
    return 10 * np.log10(np.sum(original ** 2) / (np.sum(noise ** 2) + eps))

# === Paths ===
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/librivox"
COMPRESSED_PATH = "/kaggle/input/compressed-data/compressed_musan/speech/librivox/compressed_3kbps/librivox"

# === Metric Storage ===
snr_values, sdr_values, stoi_values, pesq_values = [], [], [], []

# === Evaluation Loop ===
for root, _, files in os.walk(ORIGINAL_PATH):
    for file in sorted(files):
        if file.endswith(".wav"):
            original_file = os.path.join(root, file)
            compressed_file = os.path.join(COMPRESSED_PATH, file.replace(".wav", ".opus"))

            try:
                orig_audio, _ = librosa.load(original_file, sr=SAMPLE_RATE)
                comp_audio, _ = librosa.load(compressed_file, sr=SAMPLE_RATE)

                orig_audio = fix_length(orig_audio, TARGET_SAMPLES)
                comp_audio = fix_length(comp_audio, TARGET_SAMPLES)

                # SNR
                snr_values.append(snr(orig_audio, comp_audio))

                # SDR
                sdr, _, _, _ = bss_eval_sources(orig_audio[None, :], comp_audio[None, :])
                sdr_values.append(sdr[0])

                # STOI
                stoi_values.append(stoi(orig_audio, comp_audio, SAMPLE_RATE, extended=False))

                # PESQ
                pesq_score = pesq(SAMPLE_RATE, orig_audio, comp_audio, 'wb')
                pesq_values.append(pesq_score)

                print(f"✅ {file}: SNR={snr_values[-1]:.2f}, SDR={sdr[0]:.2f}, STOI={stoi_values[-1]:.3f}, PESQ={pesq_score:.3f}")

            except Exception as e:
                print(f"⚠️ Error processing {file}: {e}")

# === Print Averages ===
if snr_values:
    print("\n📊 Compressed Audio Evaluation (vs Original):")
    print(f"✅ Avg SNR :  {np.mean(snr_values):.2f} dB")
    print(f"✅ Avg SDR :  {np.mean(sdr_values):.2f} dB")
    print(f"✅ Avg STOI:  {np.mean(stoi_values):.3f}")
    print(f"✅ Avg PESQ:  {np.mean(pesq_values):.3f}")
else:
    print("\n⚠ No valid files processed for metric calculation.")
# Out:
# <ipython-input-21-01cc83345419>:52: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(orig_audio[None, :], comp_audio[None, :])
# ✅ speech-librivox-0000.wav: SNR=0.39, SDR=-3.40, STOI=0.747, PESQ=1.641
# ✅ speech-librivox-0001.wav: SNR=0.83, SDR=-4.23, STOI=0.717, PESQ=1.442
# ✅ speech-librivox-0002.wav: SNR=0.65, SDR=-3.31, STOI=0.803, PESQ=1.419
# ✅ speech-librivox-0003.wav: SNR=-1.02, SDR=-7.24, STOI=0.696, PESQ=1.357
# ✅ speech-librivox-0004.wav: SNR=0.75, SDR=-3.26, STOI=0.683, PESQ=1.369
# ✅ speech-librivox-0005.wav: SNR=-0.56, SDR=-3.79, STOI=0.588, PESQ=1.359
# ✅ speech-librivox-0006.wav: SNR=1.37, SDR=-2.36, STOI=0.688, PESQ=1.547
# ✅ speech-librivox-0007.wav: SNR=-1.07, SDR=-6.40, STOI=0.752, PESQ=1.332
# ✅ speech-librivox-0008.wav: SNR=1.78, SDR=0.18, STOI=0.781, PESQ=1.508
# ✅ speech-librivox-0009.wav: SNR=1.01, SDR=-2.09, STOI=0.731, PESQ=1.590
# ✅ speech-librivox-0010.wav: SNR=1.90, SDR=-0.51, STOI=0.790, PESQ=1.547
# ✅ speech-librivox-0011.wav: SNR=-4.17, SDR=-11.31, STOI=0.779, PESQ=1.757
# ✅ speech-librivox-0012.wav: SNR=0.61, SDR=-4.49, STOI=0.676, PESQ=1.344
# ✅ speech-librivox-0013.wav: SNR=-1.44, SDR=-7.45, STOI=0.699, PESQ=1.566
# ✅ speech-librivox-0014.wav: SNR=0.94, SDR=-3.09, STOI=0.797, PESQ=1.519
# ✅ speech-librivox-0015.wav: SNR=-0.49, SDR=-5.58, STOI=0.721, PESQ=1.384
# ✅ speech-librivox-0016.wav: SNR=-0.08, SDR=-4.78, STOI=0.636, PESQ=1.625
# ✅ speech-librivox-0017.wav: SNR=-1.51, SDR=-9.17, STOI=0.740, PESQ=1.505
# ✅ speech-librivox-0018.wav: SNR=0.93, SDR=-2.66, STOI=0.736, PESQ=1.442
# ✅ speech-librivox-0019.wav: SNR=1.99, SDR=-0.83, STOI=0.763, PESQ=1.468
# ✅ speech-librivox-0020.wav: SNR=-0.48, SDR=-5.18, STOI=0.748, PESQ=1.682
# ✅ speech-librivox-0021.wav: SNR=4.29, SDR=3.14, STOI=0.740, PESQ=1.374
# ✅ speech-librivox-0022.wav: SNR=1.39, SDR=-1.89, STOI=0.740, PESQ=1.263
# ✅ speech-librivox-0023.wav: SNR=0.61, SDR=-3.55, STOI=0.726, PESQ=1.577
# ✅ speech-librivox-0024.wav: SNR=-0.94, SDR=-6.34, STOI=0.716, PESQ=1.248
# ✅ speech-librivox-0025.wav: SNR=1.71, SDR=-2.38, STOI=0.686, PESQ=1.401
# ✅ speech-librivox-0026.wav: SNR=-1.75, SDR=-7.02, STOI=0.777, PESQ=1.259
# ✅ speech-librivox-0027.wav: SNR=1.97, SDR=-1.26, STOI=0.781, PESQ=1.426
# ✅ speech-librivox-0028.wav: SNR=2.80, SDR=0.55, STOI=0.773, PESQ=1.413
# ✅ speech-librivox-0029.wav: SNR=2.09, SDR=-0.75, STOI=0.749, PESQ=1.417
# ✅ speech-librivox-0030.wav: SNR=0.48, SDR=-4.82, STOI=0.692, PESQ=1.529
# ✅ speech-librivox-0031.wav: SNR=2.38, SDR=-0.90, STOI=0.722, PESQ=1.132
# ✅ speech-librivox-0032.wav: SNR=0.84, SDR=-3.61, STOI=0.740, PESQ=1.341
# ✅ speech-librivox-0033.wav: SNR=1.55, SDR=-2.19, STOI=0.705, PESQ=1.331
# ✅ speech-librivox-0034.wav: SNR=-0.19, SDR=-5.74, STOI=0.714, PESQ=1.425
# ✅ speech-librivox-0035.wav: SNR=-2.24, SDR=-10.69, STOI=0.729, PESQ=1.303
# ✅ speech-librivox-0036.wav: SNR=0.90, SDR=-3.53, STOI=0.706, PESQ=1.694
# ✅ speech-librivox-0037.wav: SNR=3.94, SDR=2.41, STOI=0.777, PESQ=1.397
# ✅ speech-librivox-0038.wav: SNR=-0.33, SDR=-6.31, STOI=0.767, PESQ=1.827
# ✅ speech-librivox-0039.wav: SNR=0.03, SDR=-4.33, STOI=0.728, PESQ=1.425
# ✅ speech-librivox-0040.wav: SNR=-2.80, SDR=-8.88, STOI=0.740, PESQ=1.656
# ✅ speech-librivox-0041.wav: SNR=-0.13, SDR=-4.13, STOI=0.726, PESQ=1.597
# ✅ speech-librivox-0042.wav: SNR=-1.83, SDR=-10.19, STOI=0.706, PESQ=1.574
# ✅ speech-librivox-0043.wav: SNR=1.10, SDR=-2.69, STOI=0.744, PESQ=1.475
# ✅ speech-librivox-0044.wav: SNR=1.09, SDR=-3.07, STOI=0.705, PESQ=1.520
# ✅ speech-librivox-0045.wav: SNR=0.02, SDR=-6.82, STOI=0.671, PESQ=1.267
# ✅ speech-librivox-0046.wav: SNR=0.74, SDR=-4.02, STOI=0.743, PESQ=1.672
# ✅ speech-librivox-0047.wav: SNR=-0.10, SDR=-6.05, STOI=0.625, PESQ=1.231
# ✅ speech-librivox-0048.wav: SNR=0.28, SDR=-5.19, STOI=0.698, PESQ=1.787
# ✅ speech-librivox-0049.wav: SNR=0.48, SDR=-5.64, STOI=0.725, PESQ=1.283
# ✅ speech-librivox-0050.wav: SNR=-0.78, SDR=-7.08, STOI=0.715, PESQ=1.396
# ✅ speech-librivox-0051.wav: SNR=0.92, SDR=-3.72, STOI=0.703, PESQ=1.325
# ✅ speech-librivox-0052.wav: SNR=0.53, SDR=-4.90, STOI=0.719, PESQ=1.445
# ✅ speech-librivox-0053.wav: SNR=-0.86, SDR=-6.23, STOI=0.768, PESQ=1.466
# ✅ speech-librivox-0054.wav: SNR=1.14, SDR=-1.76, STOI=0.789, PESQ=1.497
# ✅ speech-librivox-0055.wav: SNR=-1.99, SDR=-10.33, STOI=0.732, PESQ=1.282
# ✅ speech-librivox-0056.wav: SNR=-2.68, SDR=-8.20, STOI=0.710, PESQ=1.293
# ✅ speech-librivox-0057.wav: SNR=0.34, SDR=-5.02, STOI=0.728, PESQ=1.442
# ✅ speech-librivox-0058.wav: SNR=0.12, SDR=-5.85, STOI=0.664, PESQ=1.181
# ✅ speech-librivox-0059.wav: SNR=1.57, SDR=-1.50, STOI=0.778, PESQ=1.270
# ✅ speech-librivox-0060.wav: SNR=-0.27, SDR=-4.23, STOI=0.690, PESQ=1.310
# ✅ speech-librivox-0061.wav: SNR=2.05, SDR=-1.29, STOI=0.744, PESQ=1.204
# ✅ speech-librivox-0062.wav: SNR=0.59, SDR=-4.96, STOI=0.739, PESQ=1.527
# ✅ speech-librivox-0063.wav: SNR=1.64, SDR=-0.65, STOI=0.781, PESQ=1.484
# ✅ speech-librivox-0064.wav: SNR=0.67, SDR=-4.85, STOI=0.722, PESQ=1.287
# ✅ speech-librivox-0065.wav: SNR=-0.48, SDR=-6.09, STOI=0.637, PESQ=1.318
# ✅ speech-librivox-0066.wav: SNR=0.64, SDR=-3.33, STOI=0.778, PESQ=1.731
# ✅ speech-librivox-0067.wav: SNR=0.85, SDR=-3.77, STOI=0.719, PESQ=1.462
# ✅ speech-librivox-0068.wav: SNR=-0.21, SDR=-4.79, STOI=0.674, PESQ=1.344
# ✅ speech-librivox-0069.wav: SNR=0.03, SDR=-5.83, STOI=0.706, PESQ=1.336
# ✅ speech-librivox-0070.wav: SNR=2.66, SDR=0.49, STOI=0.688, PESQ=1.722
# ✅ speech-librivox-0071.wav: SNR=-0.97, SDR=-6.79, STOI=0.705, PESQ=1.603
# ✅ speech-librivox-0072.wav: SNR=3.74, SDR=2.19, STOI=0.714, PESQ=1.714
# ✅ speech-librivox-0073.wav: SNR=0.09, SDR=-5.15, STOI=0.714, PESQ=1.704
# ✅ speech-librivox-0074.wav: SNR=1.28, SDR=-2.94, STOI=0.683, PESQ=1.308
# ✅ speech-librivox-0075.wav: SNR=-0.15, SDR=-5.87, STOI=0.730, PESQ=1.698
# ✅ speech-librivox-0076.wav: SNR=0.24, SDR=-5.50, STOI=0.681, PESQ=1.439
# ✅ speech-librivox-0077.wav: SNR=1.31, SDR=-2.04, STOI=0.779, PESQ=1.440
# ✅ speech-librivox-0078.wav: SNR=0.51, SDR=-3.75, STOI=0.750, PESQ=1.156
# ✅ speech-librivox-0079.wav: SNR=-1.16, SDR=-8.18, STOI=0.701, PESQ=1.257
# ✅ speech-librivox-0080.wav: SNR=0.16, SDR=-1.99, STOI=0.582, PESQ=1.333
# ✅ speech-librivox-0081.wav: SNR=-3.66, SDR=-11.46, STOI=0.755, PESQ=1.295
# ✅ speech-librivox-0082.wav: SNR=-2.62, SDR=-10.58, STOI=0.702, PESQ=1.465
# ✅ speech-librivox-0083.wav: SNR=1.05, SDR=-3.53, STOI=0.700, PESQ=1.315
# ✅ speech-librivox-0084.wav: SNR=0.97, SDR=-4.43, STOI=0.681, PESQ=1.338
# ✅ speech-librivox-0085.wav: SNR=-0.77, SDR=-5.26, STOI=0.715, PESQ=1.485
# ✅ speech-librivox-0086.wav: SNR=1.26, SDR=-3.29, STOI=0.693, PESQ=1.612
# ✅ speech-librivox-0087.wav: SNR=-0.56, SDR=-5.44, STOI=0.760, PESQ=1.528
# ✅ speech-librivox-0088.wav: SNR=-0.03, SDR=-4.47, STOI=0.743, PESQ=1.331
# ✅ speech-librivox-0089.wav: SNR=1.14, SDR=-3.35, STOI=0.735, PESQ=1.479
# ✅ speech-librivox-0090.wav: SNR=-1.20, SDR=-7.92, STOI=0.743, PESQ=1.799
# ✅ speech-librivox-0091.wav: SNR=0.95, SDR=-2.81, STOI=0.678, PESQ=1.212
# ✅ speech-librivox-0092.wav: SNR=-0.12, SDR=-6.20, STOI=0.654, PESQ=1.236
# ✅ speech-librivox-0093.wav: SNR=1.24, SDR=-1.77, STOI=0.798, PESQ=1.531
# ✅ speech-librivox-0094.wav: SNR=0.78, SDR=-2.42, STOI=0.755, PESQ=1.339
# ✅ speech-librivox-0095.wav: SNR=1.35, SDR=-1.70, STOI=0.761, PESQ=1.585
# ✅ speech-librivox-0096.wav: SNR=2.51, SDR=0.11, STOI=0.771, PESQ=1.323
# ✅ speech-librivox-0097.wav: SNR=2.48, SDR=0.29, STOI=0.723, PESQ=1.229
# ✅ speech-librivox-0098.wav: SNR=2.47, SDR=-0.25, STOI=0.763, PESQ=1.334
# ✅ speech-librivox-0099.wav: SNR=2.43, SDR=0.03, STOI=0.767, PESQ=1.389
# ✅ speech-librivox-0100.wav: SNR=-2.22, SDR=-10.95, STOI=0.732, PESQ=1.186
# ✅ speech-librivox-0101.wav: SNR=2.84, SDR=0.54, STOI=0.665, PESQ=1.407
# ✅ speech-librivox-0102.wav: SNR=0.61, SDR=-5.63, STOI=0.718, PESQ=1.495
# ✅ speech-librivox-0103.wav: SNR=2.12, SDR=-0.61, STOI=0.724, PESQ=1.549
# ✅ speech-librivox-0104.wav: SNR=1.36, SDR=-2.00, STOI=0.755, PESQ=1.627
# ✅ speech-librivox-0105.wav: SNR=0.13, SDR=-5.83, STOI=0.677, PESQ=1.486
# ✅ speech-librivox-0106.wav: SNR=1.45, SDR=-2.67, STOI=0.725, PESQ=1.525
# ✅ speech-librivox-0107.wav: SNR=2.12, SDR=-1.35, STOI=0.711, PESQ=1.487
# ✅ speech-librivox-0108.wav: SNR=2.19, SDR=-0.85, STOI=0.749, PESQ=1.384
# ✅ speech-librivox-0109.wav: SNR=1.32, SDR=-2.52, STOI=0.735, PESQ=1.422
# ✅ speech-librivox-0110.wav: SNR=0.79, SDR=-3.75, STOI=0.728, PESQ=1.562
# ✅ speech-librivox-0111.wav: SNR=3.46, SDR=1.23, STOI=0.751, PESQ=1.431
# ✅ speech-librivox-0112.wav: SNR=1.56, SDR=-2.65, STOI=0.724, PESQ=1.407
# ✅ speech-librivox-0113.wav: SNR=1.89, SDR=-1.67, STOI=0.716, PESQ=1.447
# ✅ speech-librivox-0114.wav: SNR=0.40, SDR=-5.62, STOI=0.693, PESQ=1.471
# ✅ speech-librivox-0115.wav: SNR=-0.03, SDR=-4.76, STOI=0.675, PESQ=1.308
# ✅ speech-librivox-0116.wav: SNR=0.08, SDR=-5.76, STOI=0.741, PESQ=1.641
# ✅ speech-librivox-0117.wav: SNR=1.41, SDR=-2.62, STOI=0.668, PESQ=1.154
# ✅ speech-librivox-0118.wav: SNR=1.87, SDR=-1.61, STOI=0.685, PESQ=1.289
# ✅ speech-librivox-0119.wav: SNR=1.68, SDR=-0.30, STOI=0.729, PESQ=1.294
# ✅ speech-librivox-0120.wav: SNR=3.53, SDR=1.48, STOI=0.765, PESQ=1.510
# ✅ speech-librivox-0121.wav: SNR=0.88, SDR=-1.48, STOI=0.588, PESQ=1.265
# ✅ speech-librivox-0122.wav: SNR=0.36, SDR=-5.29, STOI=0.713, PESQ=1.323
# ✅ speech-librivox-0123.wav: SNR=1.52, SDR=-0.78, STOI=0.775, PESQ=1.609
# ✅ speech-librivox-0124.wav: SNR=2.20, SDR=0.50, STOI=0.701, PESQ=1.503
# ✅ speech-librivox-0125.wav: SNR=1.40, SDR=-0.71, STOI=0.697, PESQ=1.234
# ✅ speech-librivox-0126.wav: SNR=0.73, SDR=-3.85, STOI=0.712, PESQ=1.575
# ✅ speech-librivox-0127.wav: SNR=1.25, SDR=-3.43, STOI=0.701, PESQ=1.354
# ✅ speech-librivox-0128.wav: SNR=1.41, SDR=-1.69, STOI=0.754, PESQ=1.620
# ✅ speech-librivox-0129.wav: SNR=1.51, SDR=-1.10, STOI=0.718, PESQ=1.422
# ✅ speech-librivox-0130.wav: SNR=0.44, SDR=-4.43, STOI=0.738, PESQ=1.432
# ✅ speech-librivox-0131.wav: SNR=1.50, SDR=-2.15, STOI=0.735, PESQ=1.612
# ✅ speech-librivox-0132.wav: SNR=-2.37, SDR=-9.35, STOI=0.731, PESQ=1.333
# ✅ speech-librivox-0133.wav: SNR=2.59, SDR=0.08, STOI=0.757, PESQ=1.378
# ✅ speech-librivox-0134.wav: SNR=1.19, SDR=-0.89, STOI=0.786, PESQ=1.635
# ✅ speech-librivox-0135.wav: SNR=-1.53, SDR=-6.92, STOI=0.761, PESQ=1.514
# ✅ speech-librivox-0136.wav: SNR=2.28, SDR=-0.46, STOI=0.687, PESQ=1.225
# ✅ speech-librivox-0137.wav: SNR=1.25, SDR=-3.60, STOI=0.696, PESQ=1.563
# ✅ speech-librivox-0138.wav: SNR=1.24, SDR=-2.75, STOI=0.700, PESQ=1.540
# ✅ speech-librivox-0139.wav: SNR=0.37, SDR=-3.62, STOI=0.684, PESQ=1.542
# ✅ speech-librivox-0140.wav: SNR=-2.13, SDR=-10.24, STOI=0.715, PESQ=1.259
# ✅ speech-librivox-0141.wav: SNR=0.49, SDR=-1.97, STOI=0.802, PESQ=1.460
# ✅ speech-librivox-0142.wav: SNR=0.72, SDR=-3.57, STOI=0.693, PESQ=1.445
# ✅ speech-librivox-0143.wav: SNR=1.52, SDR=-1.84, STOI=0.762, PESQ=1.399
# ✅ speech-librivox-0144.wav: SNR=1.26, SDR=-2.34, STOI=0.764, PESQ=1.521
# ✅ speech-librivox-0145.wav: SNR=-0.84, SDR=-7.81, STOI=0.734, PESQ=1.554
# ✅ speech-librivox-0146.wav: SNR=1.57, SDR=-2.06, STOI=0.706, PESQ=1.479
# ✅ speech-librivox-0147.wav: SNR=-0.60, SDR=-5.05, STOI=0.528, PESQ=1.537
# ✅ speech-librivox-0148.wav: SNR=0.31, SDR=-5.64, STOI=0.710, PESQ=1.330
# ✅ speech-librivox-0149.wav: SNR=1.22, SDR=-2.86, STOI=0.779, PESQ=1.610
# ✅ speech-librivox-0150.wav: SNR=-0.52, SDR=-6.28, STOI=0.752, PESQ=1.479
# ✅ speech-librivox-0151.wav: SNR=-0.13, SDR=-5.75, STOI=0.689, PESQ=1.226
# ✅ speech-librivox-0152.wav: SNR=1.84, SDR=-1.96, STOI=0.636, PESQ=1.469
# ✅ speech-librivox-0153.wav: SNR=-1.05, SDR=-6.81, STOI=0.744, PESQ=1.303
# ✅ speech-librivox-0154.wav: SNR=0.64, SDR=-4.58, STOI=0.733, PESQ=1.470
# ✅ speech-librivox-0155.wav: SNR=0.66, SDR=-2.72, STOI=0.802, PESQ=1.521
# ✅ speech-librivox-0156.wav: SNR=-0.11, SDR=-7.66, STOI=0.642, PESQ=1.587
# ✅ speech-librivox-0157.wav: SNR=-0.55, SDR=-6.29, STOI=0.737, PESQ=1.354
# ✅ speech-librivox-0158.wav: SNR=-0.13, SDR=-5.72, STOI=0.741, PESQ=1.668
# ✅ speech-librivox-0159.wav: SNR=2.40, SDR=0.20, STOI=0.773, PESQ=1.569
# ✅ speech-librivox-0160.wav: SNR=1.56, SDR=-2.34, STOI=0.709, PESQ=1.342
# ✅ speech-librivox-0161.wav: SNR=1.87, SDR=-1.48, STOI=0.689, PESQ=1.308
# ✅ speech-librivox-0162.wav: SNR=0.99, SDR=-3.59, STOI=0.688, PESQ=1.512
# ✅ speech-librivox-0163.wav: SNR=0.46, SDR=-4.41, STOI=0.678, PESQ=1.235
# ✅ speech-librivox-0164.wav: SNR=0.55, SDR=-2.84, STOI=0.747, PESQ=1.519
# ✅ speech-librivox-0165.wav: SNR=-0.66, SDR=-6.29, STOI=0.721, PESQ=1.737
# ✅ speech-librivox-0166.wav: SNR=0.70, SDR=-5.19, STOI=0.644, PESQ=1.480
# ✅ speech-librivox-0167.wav: SNR=0.77, SDR=-2.45, STOI=0.644, PESQ=1.209
# ✅ speech-librivox-0168.wav: SNR=0.31, SDR=-5.37, STOI=0.771, PESQ=1.557
# ✅ speech-librivox-0169.wav: SNR=2.42, SDR=-0.57, STOI=0.772, PESQ=1.480
# ✅ speech-librivox-0170.wav: SNR=1.50, SDR=-2.19, STOI=0.639, PESQ=1.468
# ✅ speech-librivox-0171.wav: SNR=1.13, SDR=-2.93, STOI=0.706, PESQ=1.442
# ✅ speech-librivox-0172.wav: SNR=0.81, SDR=-3.71, STOI=0.742, PESQ=1.238
#
# 📊 Compressed Audio Evaluation (vs Original):
# ✅ Avg SNR :  0.62 dB
# ✅ Avg SDR :  -3.81 dB
# ✅ Avg STOI:  0.721
# ✅ Avg PESQ:  1.443

# %%
#analyzing using SNR librivox data of 12kbps


import os
import librosa
import numpy as np

# Function to compute SNR
def snr(original, compressed):
    min_len = min(len(original), len(compressed))
    original = original[:min_len]
    compressed = compressed[:min_len]
    
    noise = original - compressed
    eps = 1e-10  # Small value to prevent division by zero
    
    return 10 * np.log10(np.sum(original ** 2) / (np.sum(noise ** 2) + eps))

# Paths
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/librivox"
COMPRESSED_PATH = "/kaggle/input/compressed-data/compressed_musan/speech/librivox/compressed_12kbps/librivox"

# List to store SNR values
snr_values = []

# Process all files for SNR evaluation
for root, _, files in os.walk(ORIGINAL_PATH):
    for file in sorted(files):
        if file.endswith(".wav"):
            original_file = os.path.join(root, file)
            compressed_file = os.path.join(COMPRESSED_PATH, file.replace(".wav", ".opus"))
            
            # Load original and compressed audio
            try:
                original_audio, _ = librosa.load(original_file, sr=16000)  # Standard sampling rate
                compressed_audio, _ = librosa.load(compressed_file, sr=16000)
                
                # Compute SNR
                snr_value = snr(original_audio, compressed_audio)
                snr_values.append(snr_value)
                
                print(f"SNR for {file}: {snr_value:.2f} dB")
            except Exception as e:
                print(f"Error processing {file}: {e}")

# Compute and print the average SNR
if snr_values:
    avg_snr = np.mean(snr_values)
    print(f"\n✅ Average SNR for compressed dataset: {avg_snr:.2f} dB")
else:
    print("\n⚠ No valid files processed for SNR calculation.")
# Out:
# SNR for speech-librivox-0000.wav: 10.78 dB
# SNR for speech-librivox-0001.wav: 13.62 dB
# SNR for speech-librivox-0002.wav: 9.91 dB
# SNR for speech-librivox-0003.wav: 7.61 dB
# SNR for speech-librivox-0004.wav: 13.27 dB
# SNR for speech-librivox-0005.wav: 7.68 dB
# SNR for speech-librivox-0006.wav: 14.23 dB
# SNR for speech-librivox-0007.wav: 9.42 dB
# SNR for speech-librivox-0008.wav: 11.65 dB
# SNR for speech-librivox-0009.wav: 13.85 dB
# SNR for speech-librivox-0010.wav: 13.30 dB
# SNR for speech-librivox-0011.wav: 4.72 dB
# SNR for speech-librivox-0012.wav: 12.18 dB
# SNR for speech-librivox-0013.wav: 8.22 dB
# SNR for speech-librivox-0014.wav: 12.56 dB
# SNR for speech-librivox-0015.wav: 10.46 dB
# SNR for speech-librivox-0016.wav: 14.19 dB
# SNR for speech-librivox-0017.wav: 12.34 dB
# SNR for speech-librivox-0018.wav: 13.17 dB
# SNR for speech-librivox-0019.wav: 15.15 dB
# SNR for speech-librivox-0020.wav: 11.77 dB
# SNR for speech-librivox-0021.wav: 20.24 dB
# SNR for speech-librivox-0022.wav: 15.34 dB
# SNR for speech-librivox-0023.wav: 12.99 dB
# SNR for speech-librivox-0024.wav: 5.15 dB
# SNR for speech-librivox-0025.wav: 15.83 dB
# SNR for speech-librivox-0026.wav: 6.43 dB
# SNR for speech-librivox-0027.wav: 13.15 dB
# SNR for speech-librivox-0028.wav: 15.28 dB
# SNR for speech-librivox-0029.wav: 15.29 dB
# SNR for speech-librivox-0030.wav: 13.00 dB
# SNR for speech-librivox-0031.wav: 14.52 dB
# SNR for speech-librivox-0032.wav: 11.25 dB
# SNR for speech-librivox-0033.wav: 12.86 dB
# SNR for speech-librivox-0034.wav: 13.18 dB
# SNR for speech-librivox-0035.wav: 7.46 dB
# SNR for speech-librivox-0036.wav: 13.95 dB
# SNR for speech-librivox-0037.wav: 15.71 dB
# SNR for speech-librivox-0038.wav: 11.87 dB
# SNR for speech-librivox-0039.wav: 11.15 dB
# SNR for speech-librivox-0040.wav: 9.49 dB
# SNR for speech-librivox-0041.wav: 12.41 dB
# SNR for speech-librivox-0042.wav: 7.72 dB
# SNR for speech-librivox-0043.wav: 13.81 dB
# SNR for speech-librivox-0044.wav: 15.33 dB
# SNR for speech-librivox-0045.wav: 11.99 dB
# SNR for speech-librivox-0046.wav: 14.25 dB
# SNR for speech-librivox-0047.wav: 10.96 dB
# SNR for speech-librivox-0048.wav: 10.78 dB
# SNR for speech-librivox-0049.wav: 10.76 dB
# SNR for speech-librivox-0050.wav: 10.66 dB
# SNR for speech-librivox-0051.wav: 13.06 dB
# SNR for speech-librivox-0052.wav: 12.76 dB
# SNR for speech-librivox-0053.wav: 11.12 dB
# SNR for speech-librivox-0054.wav: 13.20 dB
# SNR for speech-librivox-0055.wav: 4.91 dB
# SNR for speech-librivox-0056.wav: 6.52 dB
# SNR for speech-librivox-0057.wav: 14.26 dB
# SNR for speech-librivox-0058.wav: 6.27 dB
# SNR for speech-librivox-0059.wav: 11.22 dB
# SNR for speech-librivox-0060.wav: 9.22 dB
# SNR for speech-librivox-0061.wav: 15.42 dB
# SNR for speech-librivox-0062.wav: 14.85 dB
# SNR for speech-librivox-0063.wav: 14.12 dB
# SNR for speech-librivox-0064.wav: 13.12 dB
# SNR for speech-librivox-0065.wav: 10.38 dB
# SNR for speech-librivox-0066.wav: 13.34 dB
# SNR for speech-librivox-0067.wav: 11.37 dB
# SNR for speech-librivox-0068.wav: 7.81 dB
# SNR for speech-librivox-0069.wav: 12.07 dB
# SNR for speech-librivox-0070.wav: 18.01 dB
# SNR for speech-librivox-0071.wav: 12.07 dB
# SNR for speech-librivox-0072.wav: 17.96 dB
# SNR for speech-librivox-0073.wav: 13.76 dB
# SNR for speech-librivox-0074.wav: 11.35 dB
# SNR for speech-librivox-0075.wav: 12.86 dB
# SNR for speech-librivox-0076.wav: 11.47 dB
# SNR for speech-librivox-0077.wav: 12.70 dB
# SNR for speech-librivox-0078.wav: 10.76 dB
# SNR for speech-librivox-0079.wav: 9.07 dB
# SNR for speech-librivox-0080.wav: 10.69 dB
# SNR for speech-librivox-0081.wav: 3.25 dB
# SNR for speech-librivox-0082.wav: 5.65 dB
# SNR for speech-librivox-0083.wav: 13.86 dB
# SNR for speech-librivox-0084.wav: 16.79 dB
# SNR for speech-librivox-0085.wav: 9.39 dB
# SNR for speech-librivox-0086.wav: 15.89 dB
# SNR for speech-librivox-0087.wav: 10.97 dB
# SNR for speech-librivox-0088.wav: 6.25 dB
# SNR for speech-librivox-0089.wav: 10.81 dB
# SNR for speech-librivox-0090.wav: 8.66 dB
# SNR for speech-librivox-0091.wav: 4.65 dB
# SNR for speech-librivox-0092.wav: 10.19 dB
# SNR for speech-librivox-0093.wav: 11.41 dB
# SNR for speech-librivox-0094.wav: 10.52 dB
# SNR for speech-librivox-0095.wav: 13.92 dB
# SNR for speech-librivox-0096.wav: 14.70 dB
# SNR for speech-librivox-0097.wav: 14.88 dB
# SNR for speech-librivox-0098.wav: 14.85 dB
# SNR for speech-librivox-0099.wav: 14.00 dB
# SNR for speech-librivox-0100.wav: 3.37 dB
# SNR for speech-librivox-0101.wav: 13.15 dB
# SNR for speech-librivox-0102.wav: 13.50 dB
# SNR for speech-librivox-0103.wav: 16.13 dB
# SNR for speech-librivox-0104.wav: 15.91 dB
# SNR for speech-librivox-0105.wav: 12.87 dB
# SNR for speech-librivox-0106.wav: 13.33 dB
# SNR for speech-librivox-0107.wav: 15.22 dB
# SNR for speech-librivox-0108.wav: 12.54 dB
# SNR for speech-librivox-0109.wav: 13.77 dB
# SNR for speech-librivox-0110.wav: 13.76 dB
# SNR for speech-librivox-0111.wav: 19.73 dB
# SNR for speech-librivox-0112.wav: 14.92 dB
# SNR for speech-librivox-0113.wav: 15.24 dB
# SNR for speech-librivox-0114.wav: 13.34 dB
# SNR for speech-librivox-0115.wav: 12.22 dB
# SNR for speech-librivox-0116.wav: 8.67 dB
# SNR for speech-librivox-0117.wav: 16.07 dB
# SNR for speech-librivox-0118.wav: 16.17 dB
# SNR for speech-librivox-0119.wav: 9.54 dB
# SNR for speech-librivox-0120.wav: 15.09 dB
# SNR for speech-librivox-0121.wav: 9.17 dB
# SNR for speech-librivox-0122.wav: 13.82 dB
# SNR for speech-librivox-0123.wav: 13.56 dB
# SNR for speech-librivox-0124.wav: 14.32 dB
# SNR for speech-librivox-0125.wav: 10.95 dB
# SNR for speech-librivox-0126.wav: 12.75 dB
# SNR for speech-librivox-0127.wav: 13.31 dB
# SNR for speech-librivox-0128.wav: 12.58 dB
# SNR for speech-librivox-0129.wav: 11.63 dB
# SNR for speech-librivox-0130.wav: 9.43 dB
# SNR for speech-librivox-0131.wav: 13.05 dB
# SNR for speech-librivox-0132.wav: 6.03 dB
# SNR for speech-librivox-0133.wav: 11.91 dB
# SNR for speech-librivox-0134.wav: 13.05 dB
# SNR for speech-librivox-0135.wav: 7.22 dB
# SNR for speech-librivox-0136.wav: 13.10 dB
# SNR for speech-librivox-0137.wav: 14.17 dB
# SNR for speech-librivox-0138.wav: 15.83 dB
# SNR for speech-librivox-0139.wav: 13.02 dB
# SNR for speech-librivox-0140.wav: 5.48 dB
# SNR for speech-librivox-0141.wav: 10.56 dB
# SNR for speech-librivox-0142.wav: 11.77 dB
# SNR for speech-librivox-0143.wav: 15.06 dB
# SNR for speech-librivox-0144.wav: 13.63 dB
# SNR for speech-librivox-0145.wav: 8.32 dB
# SNR for speech-librivox-0146.wav: 14.64 dB
# SNR for speech-librivox-0147.wav: 9.88 dB
# SNR for speech-librivox-0148.wav: 12.93 dB
# SNR for speech-librivox-0149.wav: 12.69 dB
# SNR for speech-librivox-0150.wav: 10.91 dB
# SNR for speech-librivox-0151.wav: 11.23 dB
# SNR for speech-librivox-0152.wav: 16.90 dB
# SNR for speech-librivox-0153.wav: 6.53 dB
# SNR for speech-librivox-0154.wav: 11.84 dB
# SNR for speech-librivox-0155.wav: 12.72 dB
# SNR for speech-librivox-0156.wav: 13.27 dB
# SNR for speech-librivox-0157.wav: 12.97 dB
# SNR for speech-librivox-0158.wav: 12.76 dB
# SNR for speech-librivox-0159.wav: 13.76 dB
# SNR for speech-librivox-0160.wav: 15.52 dB
# SNR for speech-librivox-0161.wav: 11.08 dB
# SNR for speech-librivox-0162.wav: 13.41 dB
# SNR for speech-librivox-0163.wav: 11.12 dB
# SNR for speech-librivox-0164.wav: 11.76 dB
# SNR for speech-librivox-0165.wav: 8.08 dB
# SNR for speech-librivox-0166.wav: 13.40 dB
# SNR for speech-librivox-0167.wav: 6.78 dB
# SNR for speech-librivox-0168.wav: 12.77 dB
# SNR for speech-librivox-0169.wav: 14.95 dB
# SNR for speech-librivox-0170.wav: 16.67 dB
# SNR for speech-librivox-0171.wav: 15.62 dB
# SNR for speech-librivox-0172.wav: 11.39 dB
#
# ✅ Average SNR for compressed dataset: 12.10 dB

# %%
#analyzing using SNR,SDR,STOI and PESQ for librivox data of 12kbps

import os
import librosa
import numpy as np
from pesq import pesq
from pystoi import stoi
from mir_eval.separation import bss_eval_sources

# === Constants ===
SAMPLE_RATE = 16000
DURATION = 30
TARGET_SAMPLES = SAMPLE_RATE * DURATION

# === Evaluation Functions ===
def fix_length(audio, target_len):
    if len(audio) > target_len:
        return audio[:target_len]
    return np.pad(audio, (0, target_len - len(audio)))

def snr(original, compressed):
    min_len = min(len(original), len(compressed))
    original = original[:min_len]
    compressed = compressed[:min_len]
    noise = original - compressed
    eps = 1e-10
    return 10 * np.log10(np.sum(original ** 2) / (np.sum(noise ** 2) + eps))

# === Paths ===
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/librivox"
COMPRESSED_PATH = "/kaggle/input/compressed-data/compressed_musan/speech/librivox/compressed_12kbps/librivox"

# === Metric Storage ===
snr_values, sdr_values, stoi_values, pesq_values = [], [], [], []

# === Evaluation Loop ===
for root, _, files in os.walk(ORIGINAL_PATH):
    for file in sorted(files):
        if file.endswith(".wav"):
            original_file = os.path.join(root, file)
            compressed_file = os.path.join(COMPRESSED_PATH, file.replace(".wav", ".opus"))

            try:
                orig_audio, _ = librosa.load(original_file, sr=SAMPLE_RATE)
                comp_audio, _ = librosa.load(compressed_file, sr=SAMPLE_RATE)

                orig_audio = fix_length(orig_audio, TARGET_SAMPLES)
                comp_audio = fix_length(comp_audio, TARGET_SAMPLES)

                # SNR
                snr_values.append(snr(orig_audio, comp_audio))

                # SDR
                sdr, _, _, _ = bss_eval_sources(orig_audio[None, :], comp_audio[None, :])
                sdr_values.append(sdr[0])

                # STOI
                stoi_values.append(stoi(orig_audio, comp_audio, SAMPLE_RATE, extended=False))

                # PESQ
                pesq_score = pesq(SAMPLE_RATE, orig_audio, comp_audio, 'wb')
                pesq_values.append(pesq_score)

                print(f"✅ {file}: SNR={snr_values[-1]:.2f}, SDR={sdr[0]:.2f}, STOI={stoi_values[-1]:.3f}, PESQ={pesq_score:.3f}")

            except Exception as e:
                print(f"⚠️ Error processing {file}: {e}")

# === Print Averages ===
if snr_values:
    print("\n📊 Compressed Audio Evaluation (vs Original):")
    print(f"✅ Avg SNR :  {np.mean(snr_values):.2f} dB")
    print(f"✅ Avg SDR :  {np.mean(sdr_values):.2f} dB")
    print(f"✅ Avg STOI:  {np.mean(stoi_values):.3f}")
    print(f"✅ Avg PESQ:  {np.mean(pesq_values):.3f}")
else:
    print("\n⚠ No valid files processed for metric calculation.")
# Out:
# <ipython-input-22-5603664c4e92>:52: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(orig_audio[None, :], comp_audio[None, :])
# ✅ speech-librivox-0000.wav: SNR=10.79, SDR=11.22, STOI=0.978, PESQ=4.174
# ✅ speech-librivox-0001.wav: SNR=13.07, SDR=13.49, STOI=0.974, PESQ=4.003
# ✅ speech-librivox-0002.wav: SNR=9.75, SDR=10.12, STOI=0.975, PESQ=3.720
# ✅ speech-librivox-0003.wav: SNR=6.81, SDR=7.15, STOI=0.972, PESQ=4.014
# ✅ speech-librivox-0004.wav: SNR=13.96, SDR=14.50, STOI=0.966, PESQ=3.896
# ✅ speech-librivox-0005.wav: SNR=9.81, SDR=10.32, STOI=0.835, PESQ=3.767
# ✅ speech-librivox-0006.wav: SNR=15.46, SDR=16.11, STOI=0.968, PESQ=4.107
# ✅ speech-librivox-0007.wav: SNR=8.84, SDR=8.94, STOI=0.980, PESQ=3.665
# ✅ speech-librivox-0008.wav: SNR=10.52, SDR=11.37, STOI=0.977, PESQ=3.751
# ✅ speech-librivox-0009.wav: SNR=13.14, SDR=13.64, STOI=0.957, PESQ=3.867
# ✅ speech-librivox-0010.wav: SNR=14.02, SDR=14.40, STOI=0.980, PESQ=3.848
# ✅ speech-librivox-0011.wav: SNR=6.19, SDR=5.63, STOI=0.963, PESQ=3.874
# ✅ speech-librivox-0012.wav: SNR=11.78, SDR=12.35, STOI=0.971, PESQ=3.941
# ✅ speech-librivox-0013.wav: SNR=9.54, SDR=9.79, STOI=0.970, PESQ=4.024
# ✅ speech-librivox-0014.wav: SNR=13.12, SDR=13.66, STOI=0.978, PESQ=3.972
# ✅ speech-librivox-0015.wav: SNR=11.27, SDR=11.69, STOI=0.973, PESQ=4.063
# ✅ speech-librivox-0016.wav: SNR=13.90, SDR=14.10, STOI=0.811, PESQ=4.165
# ✅ speech-librivox-0017.wav: SNR=12.17, SDR=12.27, STOI=0.975, PESQ=3.898
# ✅ speech-librivox-0018.wav: SNR=13.09, SDR=13.61, STOI=0.974, PESQ=3.897
# ✅ speech-librivox-0019.wav: SNR=15.15, SDR=15.67, STOI=0.978, PESQ=3.924
# ✅ speech-librivox-0020.wav: SNR=11.63, SDR=11.93, STOI=0.972, PESQ=4.105
# ✅ speech-librivox-0021.wav: SNR=20.12, SDR=20.72, STOI=0.970, PESQ=3.786
# ✅ speech-librivox-0022.wav: SNR=15.31, SDR=15.77, STOI=0.972, PESQ=3.929
# ✅ speech-librivox-0023.wav: SNR=13.36, SDR=13.55, STOI=0.977, PESQ=3.985
# ✅ speech-librivox-0024.wav: SNR=4.78, SDR=4.68, STOI=0.961, PESQ=3.759
# ✅ speech-librivox-0025.wav: SNR=15.56, SDR=16.18, STOI=0.964, PESQ=3.891
# ✅ speech-librivox-0026.wav: SNR=4.93, SDR=4.76, STOI=0.972, PESQ=3.921
# ✅ speech-librivox-0027.wav: SNR=13.55, SDR=14.40, STOI=0.978, PESQ=3.930
# ✅ speech-librivox-0028.wav: SNR=16.41, SDR=17.14, STOI=0.978, PESQ=3.863
# ✅ speech-librivox-0029.wav: SNR=14.84, SDR=15.64, STOI=0.975, PESQ=3.820
# ✅ speech-librivox-0030.wav: SNR=13.32, SDR=13.81, STOI=0.972, PESQ=4.114
# ✅ speech-librivox-0031.wav: SNR=15.92, SDR=16.54, STOI=0.972, PESQ=3.985
# ✅ speech-librivox-0032.wav: SNR=11.82, SDR=12.27, STOI=0.974, PESQ=3.862
# ✅ speech-librivox-0033.wav: SNR=13.01, SDR=13.38, STOI=0.972, PESQ=3.733
# ✅ speech-librivox-0034.wav: SNR=12.28, SDR=12.76, STOI=0.974, PESQ=4.022
# ✅ speech-librivox-0035.wav: SNR=6.81, SDR=6.63, STOI=0.966, PESQ=3.995
# ✅ speech-librivox-0036.wav: SNR=14.95, SDR=15.28, STOI=0.973, PESQ=4.071
# ✅ speech-librivox-0037.wav: SNR=17.04, SDR=17.60, STOI=0.975, PESQ=3.806
# ✅ speech-librivox-0038.wav: SNR=12.31, SDR=12.53, STOI=0.981, PESQ=4.243
# ✅ speech-librivox-0039.wav: SNR=12.55, SDR=12.92, STOI=0.972, PESQ=3.855
# ✅ speech-librivox-0040.wav: SNR=9.77, SDR=9.71, STOI=0.969, PESQ=3.562
# ✅ speech-librivox-0041.wav: SNR=12.15, SDR=12.61, STOI=0.967, PESQ=3.930
# ✅ speech-librivox-0042.wav: SNR=7.30, SDR=6.93, STOI=0.972, PESQ=3.382
# ✅ speech-librivox-0043.wav: SNR=13.06, SDR=13.54, STOI=0.968, PESQ=4.072
# ✅ speech-librivox-0044.wav: SNR=14.48, SDR=14.90, STOI=0.978, PESQ=4.026
# ✅ speech-librivox-0045.wav: SNR=11.56, SDR=11.77, STOI=0.966, PESQ=3.565
# ✅ speech-librivox-0046.wav: SNR=14.45, SDR=14.79, STOI=0.978, PESQ=4.225
# ✅ speech-librivox-0047.wav: SNR=10.07, SDR=10.58, STOI=0.947, PESQ=3.452
# ✅ speech-librivox-0048.wav: SNR=12.51, SDR=12.92, STOI=0.977, PESQ=4.273
# ✅ speech-librivox-0049.wav: SNR=10.91, SDR=11.30, STOI=0.975, PESQ=3.849
# ✅ speech-librivox-0050.wav: SNR=9.78, SDR=9.99, STOI=0.960, PESQ=3.914
# ✅ speech-librivox-0051.wav: SNR=14.09, SDR=14.41, STOI=0.976, PESQ=3.928
# ✅ speech-librivox-0052.wav: SNR=12.30, SDR=12.67, STOI=0.975, PESQ=4.060
# ✅ speech-librivox-0053.wav: SNR=11.46, SDR=11.52, STOI=0.979, PESQ=3.974
# ✅ speech-librivox-0054.wav: SNR=13.35, SDR=13.92, STOI=0.980, PESQ=4.017
# ✅ speech-librivox-0055.wav: SNR=4.89, SDR=4.37, STOI=0.973, PESQ=3.892
# ✅ speech-librivox-0056.wav: SNR=8.17, SDR=8.18, STOI=0.962, PESQ=3.954
# ✅ speech-librivox-0057.wav: SNR=14.47, SDR=14.88, STOI=0.979, PESQ=4.073
# ✅ speech-librivox-0058.wav: SNR=6.31, SDR=6.57, STOI=0.959, PESQ=3.404
# ✅ speech-librivox-0059.wav: SNR=11.48, SDR=11.90, STOI=0.964, PESQ=2.449
# ✅ speech-librivox-0060.wav: SNR=9.34, SDR=9.83, STOI=0.906, PESQ=3.346

# %%
#analyzing using SNR for us-gov data of 12kbps


import os
import librosa
import numpy as np

# Function to compute SNR
def snr(original, compressed):
    min_len = min(len(original), len(compressed))
    original = original[:min_len]
    compressed = compressed[:min_len]
    
    noise = original - compressed
    eps = 1e-10  # Small value to prevent division by zero
    
    return 10 * np.log10(np.sum(original ** 2) / (np.sum(noise ** 2) + eps))

# Paths
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/us-gov"
COMPRESSED_PATH = "/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_12kbps"

# List to store SNR values
snr_values = []
file_count = 0
MAX_FILES = 150  # Limit to first 150 files

# Process files for SNR evaluation
for root, _, files in os.walk(ORIGINAL_PATH):
    for file in sorted(files):
        if file.endswith(".wav"):
            if file_count >= MAX_FILES:
                break  # Stop after processing 150 files
            
            original_file = os.path.join(root, file)
            compressed_file = os.path.join(COMPRESSED_PATH, file.replace(".wav", ".opus"))
            
            # Load original and compressed audio
            try:
                original_audio, _ = librosa.load(original_file, sr=16000)  # Standard sampling rate
                compressed_audio, _ = librosa.load(compressed_file, sr=16000)
                
                # Compute SNR
                snr_value = snr(original_audio, compressed_audio)
                snr_values.append(snr_value)
                
                print(f"SNR for {file}: {snr_value:.2f} dB")
                file_count += 1
            except Exception as e:
                print(f"Error processing {file}: {e}")

# Compute and print the average SNR
if snr_values:
    avg_snr = np.mean(snr_values)
    print(f"\n✅ Average SNR for compressed dataset (first {MAX_FILES} files): {avg_snr:.2f} dB")
else:
    print("\n⚠ No valid files processed for SNR calculation.")
# Out:
# SNR for speech-us-gov-0000.wav: 15.61 dB
# SNR for speech-us-gov-0001.wav: 15.80 dB
# SNR for speech-us-gov-0002.wav: 13.65 dB
# SNR for speech-us-gov-0003.wav: 13.93 dB
# SNR for speech-us-gov-0004.wav: 12.47 dB
# SNR for speech-us-gov-0005.wav: 9.54 dB
# SNR for speech-us-gov-0006.wav: 10.81 dB
# SNR for speech-us-gov-0007.wav: 9.85 dB
# SNR for speech-us-gov-0008.wav: 10.54 dB
# SNR for speech-us-gov-0009.wav: 11.35 dB
# SNR for speech-us-gov-0010.wav: 11.34 dB
# SNR for speech-us-gov-0011.wav: 10.44 dB
# SNR for speech-us-gov-0012.wav: 10.65 dB
# SNR for speech-us-gov-0013.wav: 9.88 dB
# SNR for speech-us-gov-0014.wav: 9.36 dB
# SNR for speech-us-gov-0015.wav: 12.77 dB
# SNR for speech-us-gov-0016.wav: 13.95 dB
# SNR for speech-us-gov-0017.wav: 12.58 dB
# SNR for speech-us-gov-0018.wav: 12.63 dB
# SNR for speech-us-gov-0019.wav: 12.85 dB
# SNR for speech-us-gov-0020.wav: 15.87 dB
# SNR for speech-us-gov-0021.wav: 12.67 dB
# SNR for speech-us-gov-0022.wav: 12.40 dB
# SNR for speech-us-gov-0023.wav: 12.50 dB
# SNR for speech-us-gov-0024.wav: 13.05 dB
# SNR for speech-us-gov-0025.wav: 12.90 dB
# SNR for speech-us-gov-0026.wav: 12.93 dB
# SNR for speech-us-gov-0027.wav: 13.47 dB
# SNR for speech-us-gov-0028.wav: 12.16 dB
# SNR for speech-us-gov-0029.wav: 12.69 dB
# SNR for speech-us-gov-0030.wav: 13.39 dB
# SNR for speech-us-gov-0031.wav: 13.93 dB
# SNR for speech-us-gov-0032.wav: 12.44 dB
# SNR for speech-us-gov-0033.wav: 12.57 dB
# SNR for speech-us-gov-0034.wav: 13.31 dB
# SNR for speech-us-gov-0035.wav: 13.44 dB
# SNR for speech-us-gov-0036.wav: 13.09 dB
# SNR for speech-us-gov-0037.wav: 12.88 dB
# SNR for speech-us-gov-0038.wav: 12.78 dB
# SNR for speech-us-gov-0039.wav: 12.15 dB
# SNR for speech-us-gov-0040.wav: 12.30 dB
# SNR for speech-us-gov-0041.wav: 12.49 dB
# SNR for speech-us-gov-0042.wav: 11.29 dB
# SNR for speech-us-gov-0043.wav: 11.48 dB
# SNR for speech-us-gov-0044.wav: 11.32 dB
# SNR for speech-us-gov-0045.wav: 10.56 dB
# SNR for speech-us-gov-0046.wav: 13.46 dB
# SNR for speech-us-gov-0047.wav: 13.60 dB
# SNR for speech-us-gov-0048.wav: 12.31 dB
# SNR for speech-us-gov-0049.wav: 12.19 dB
# SNR for speech-us-gov-0050.wav: 12.44 dB
# SNR for speech-us-gov-0051.wav: 13.09 dB
# SNR for speech-us-gov-0052.wav: 13.11 dB
# SNR for speech-us-gov-0053.wav: 13.03 dB
# SNR for speech-us-gov-0054.wav: 12.78 dB
# SNR for speech-us-gov-0055.wav: 12.57 dB
# SNR for speech-us-gov-0056.wav: 11.77 dB
# SNR for speech-us-gov-0057.wav: 12.44 dB
# SNR for speech-us-gov-0058.wav: 12.51 dB
# SNR for speech-us-gov-0059.wav: 13.39 dB
# SNR for speech-us-gov-0060.wav: 13.54 dB
# SNR for speech-us-gov-0061.wav: 12.78 dB
# SNR for speech-us-gov-0062.wav: 12.48 dB
# SNR for speech-us-gov-0063.wav: 11.40 dB
# SNR for speech-us-gov-0064.wav: 11.75 dB
# SNR for speech-us-gov-0065.wav: 11.70 dB
# SNR for speech-us-gov-0066.wav: 12.76 dB
# SNR for speech-us-gov-0067.wav: 12.28 dB
# SNR for speech-us-gov-0068.wav: 12.08 dB
# SNR for speech-us-gov-0069.wav: 12.13 dB
# SNR for speech-us-gov-0070.wav: 13.25 dB
# SNR for speech-us-gov-0071.wav: 11.98 dB
# SNR for speech-us-gov-0072.wav: 12.92 dB
# SNR for speech-us-gov-0073.wav: 11.97 dB
# SNR for speech-us-gov-0074.wav: 13.03 dB
# SNR for speech-us-gov-0075.wav: 13.27 dB
# SNR for speech-us-gov-0076.wav: 13.43 dB
# SNR for speech-us-gov-0077.wav: 12.84 dB
# SNR for speech-us-gov-0078.wav: 13.35 dB
# SNR for speech-us-gov-0079.wav: 13.19 dB
# SNR for speech-us-gov-0080.wav: 11.35 dB
# SNR for speech-us-gov-0081.wav: 13.16 dB
# SNR for speech-us-gov-0082.wav: 13.19 dB
# SNR for speech-us-gov-0083.wav: 12.96 dB
# SNR for speech-us-gov-0084.wav: 14.09 dB
# SNR for speech-us-gov-0085.wav: 14.18 dB
# SNR for speech-us-gov-0086.wav: 14.87 dB
# SNR for speech-us-gov-0087.wav: 14.45 dB
# SNR for speech-us-gov-0088.wav: 14.61 dB
# SNR for speech-us-gov-0089.wav: 13.51 dB
# SNR for speech-us-gov-0090.wav: 12.69 dB
# SNR for speech-us-gov-0091.wav: 13.56 dB
# SNR for speech-us-gov-0092.wav: 11.00 dB
# SNR for speech-us-gov-0093.wav: 10.87 dB
# SNR for speech-us-gov-0094.wav: 11.14 dB
# SNR for speech-us-gov-0095.wav: 10.92 dB
# SNR for speech-us-gov-0096.wav: 11.67 dB
# SNR for speech-us-gov-0097.wav: 10.62 dB
# SNR for speech-us-gov-0098.wav: 9.86 dB
# SNR for speech-us-gov-0099.wav: 9.43 dB
# SNR for speech-us-gov-0100.wav: 10.03 dB
# SNR for speech-us-gov-0101.wav: 10.16 dB
# SNR for speech-us-gov-0102.wav: 10.51 dB
# SNR for speech-us-gov-0103.wav: 9.47 dB
# SNR for speech-us-gov-0104.wav: 13.95 dB
# SNR for speech-us-gov-0105.wav: 13.81 dB
# SNR for speech-us-gov-0106.wav: 12.85 dB
# SNR for speech-us-gov-0107.wav: 14.41 dB
# SNR for speech-us-gov-0108.wav: 13.61 dB
# SNR for speech-us-gov-0109.wav: 13.47 dB
# SNR for speech-us-gov-0110.wav: 13.36 dB
# SNR for speech-us-gov-0111.wav: 13.23 dB
# SNR for speech-us-gov-0112.wav: 12.25 dB
# SNR for speech-us-gov-0113.wav: 12.86 dB
# SNR for speech-us-gov-0114.wav: 12.04 dB
# SNR for speech-us-gov-0115.wav: 12.08 dB
# SNR for speech-us-gov-0116.wav: 12.17 dB
# SNR for speech-us-gov-0117.wav: 12.67 dB
# SNR for speech-us-gov-0118.wav: 12.54 dB
# SNR for speech-us-gov-0119.wav: 12.38 dB
# SNR for speech-us-gov-0120.wav: 12.21 dB
# SNR for speech-us-gov-0121.wav: 12.83 dB
# SNR for speech-us-gov-0122.wav: 12.12 dB
# SNR for speech-us-gov-0123.wav: 12.89 dB
# SNR for speech-us-gov-0124.wav: 12.03 dB
# SNR for speech-us-gov-0125.wav: 11.34 dB
# SNR for speech-us-gov-0126.wav: 12.19 dB
# SNR for speech-us-gov-0127.wav: 11.84 dB
# SNR for speech-us-gov-0128.wav: 11.42 dB
# SNR for speech-us-gov-0129.wav: 12.09 dB
# SNR for speech-us-gov-0130.wav: 12.40 dB
# SNR for speech-us-gov-0131.wav: 15.25 dB
# SNR for speech-us-gov-0132.wav: 14.40 dB
# SNR for speech-us-gov-0133.wav: 14.50 dB
# SNR for speech-us-gov-0134.wav: 13.83 dB
# SNR for speech-us-gov-0135.wav: 14.25 dB
# SNR for speech-us-gov-0136.wav: 14.95 dB
# SNR for speech-us-gov-0137.wav: 14.97 dB
# SNR for speech-us-gov-0138.wav: 15.20 dB
# SNR for speech-us-gov-0139.wav: 15.23 dB
# SNR for speech-us-gov-0140.wav: 14.73 dB
# SNR for speech-us-gov-0141.wav: 12.83 dB
# SNR for speech-us-gov-0142.wav: 13.33 dB
# SNR for speech-us-gov-0143.wav: 11.83 dB
# SNR for speech-us-gov-0144.wav: 12.57 dB
# SNR for speech-us-gov-0145.wav: 12.40 dB
# SNR for speech-us-gov-0146.wav: 12.54 dB
# SNR for speech-us-gov-0147.wav: 13.89 dB
# SNR for speech-us-gov-0148.wav: 12.78 dB
# SNR for speech-us-gov-0149.wav: 12.87 dB
#
# ✅ Average SNR for compressed dataset (first 150 files): 12.62 dB

# %%
#analyzing using SNR,SDR,STOI and PESQ for us-gov data of 12kbps


import os
import librosa
import numpy as np
from pesq import pesq
from pystoi import stoi
from mir_eval.separation import bss_eval_sources

# === Constants ===
SAMPLE_RATE = 16000
DURATION = 30
TARGET_SAMPLES = SAMPLE_RATE * DURATION

# === Evaluation Functions ===
def fix_length(audio, target_len):
    if len(audio) > target_len:
        return audio[:target_len]
    return np.pad(audio, (0, target_len - len(audio)))

def snr(original, compressed):
    min_len = min(len(original), len(compressed))
    original = original[:min_len]
    compressed = compressed[:min_len]
    noise = original - compressed
    eps = 1e-10
    return 10 * np.log10(np.sum(original ** 2) / (np.sum(noise ** 2) + eps))

# === Paths ===
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/us-gov"
COMPRESSED_PATH = "/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_12kbps"

# === Metric Storage ===
snr_values, sdr_values, stoi_values, pesq_values = [], [], [], []

# === Evaluation Loop ===
for root, _, files in os.walk(ORIGINAL_PATH):
    for file in sorted(files):
        if file.endswith(".wav"):
            original_file = os.path.join(root, file)
            compressed_file = os.path.join(COMPRESSED_PATH, file.replace(".wav", ".opus"))

            try:
                orig_audio, _ = librosa.load(original_file, sr=SAMPLE_RATE)
                comp_audio, _ = librosa.load(compressed_file, sr=SAMPLE_RATE)

                orig_audio = fix_length(orig_audio, TARGET_SAMPLES)
                comp_audio = fix_length(comp_audio, TARGET_SAMPLES)

                # SNR
                snr_values.append(snr(orig_audio, comp_audio))

                # SDR
                sdr, _, _, _ = bss_eval_sources(orig_audio[None, :], comp_audio[None, :])
                sdr_values.append(sdr[0])

                # STOI
                stoi_values.append(stoi(orig_audio, comp_audio, SAMPLE_RATE, extended=False))

                # PESQ
                pesq_score = pesq(SAMPLE_RATE, orig_audio, comp_audio, 'wb')
                pesq_values.append(pesq_score)

                print(f"✅ {file}: SNR={snr_values[-1]:.2f}, SDR={sdr[0]:.2f}, STOI={stoi_values[-1]:.3f}, PESQ={pesq_score:.3f}")

            except Exception as e:
                print(f"⚠️ Error processing {file}: {e}")

# === Print Averages ===
if snr_values:
    print("\n📊 Compressed Audio Evaluation (vs Original):")
    print(f"✅ Avg SNR :  {np.mean(snr_values):.2f} dB")
    print(f"✅ Avg SDR :  {np.mean(sdr_values):.2f} dB")
    print(f"✅ Avg STOI:  {np.mean(stoi_values):.3f}")
    print(f"✅ Avg PESQ:  {np.mean(pesq_values):.3f}")
else:
    print("\n⚠ No valid files processed for metric calculation.")

# %%
#analyzing using SNR for us-gov data of 3kbps


import os
import librosa
import numpy as np

# Function to compute SNR
def snr(original, compressed):
    min_len = min(len(original), len(compressed))
    original = original[:min_len]
    compressed = compressed[:min_len]
    
    noise = original - compressed
    eps = 1e-10  # Small value to prevent division by zero
    
    return 10 * np.log10(np.sum(original ** 2) / (np.sum(noise ** 2) + eps))

# Paths
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/us-gov"
COMPRESSED_PATH = "/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps"

# List to store SNR values
snr_values = []
file_count = 0
MAX_FILES = 150  # Limit to first 150 files

# Process files for SNR evaluation
for root, _, files in os.walk(ORIGINAL_PATH):
    for file in sorted(files):
        if file.endswith(".wav"):
            if file_count >= MAX_FILES:
                break  # Stop after processing 150 files
            
            original_file = os.path.join(root, file)
            compressed_file = os.path.join(COMPRESSED_PATH, file.replace(".wav", ".opus"))
            
            # Load original and compressed audio
            try:
                original_audio, _ = librosa.load(original_file, sr=16000)  # Standard sampling rate
                compressed_audio, _ = librosa.load(compressed_file, sr=16000)
                
                # Compute SNR
                snr_value = snr(original_audio, compressed_audio)
                snr_values.append(snr_value)
                
                print(f"SNR for {file}: {snr_value:.2f} dB")
                file_count += 1
            except Exception as e:
                print(f"Error processing {file}: {e}")

# Compute and print the average SNR
if snr_values:
    avg_snr = np.mean(snr_values)
    print(f"\n✅ Average SNR for compressed dataset (first {MAX_FILES} files): {avg_snr:.2f} dB")
else:
    print("\n⚠ No valid files processed for SNR calculation.")
# Out:
# SNR for speech-us-gov-0000.wav: 1.62 dB
# SNR for speech-us-gov-0001.wav: 1.46 dB
# SNR for speech-us-gov-0002.wav: 1.07 dB
# SNR for speech-us-gov-0003.wav: 0.40 dB
# SNR for speech-us-gov-0004.wav: -0.61 dB
# SNR for speech-us-gov-0005.wav: -2.82 dB
# SNR for speech-us-gov-0006.wav: -0.72 dB
# SNR for speech-us-gov-0007.wav: -1.63 dB
# SNR for speech-us-gov-0008.wav: -1.24 dB
# SNR for speech-us-gov-0009.wav: -0.21 dB
# SNR for speech-us-gov-0010.wav: -0.89 dB
# SNR for speech-us-gov-0011.wav: -1.35 dB
# SNR for speech-us-gov-0012.wav: -1.08 dB
# SNR for speech-us-gov-0013.wav: -1.43 dB
# SNR for speech-us-gov-0014.wav: -1.86 dB
# SNR for speech-us-gov-0015.wav: -0.19 dB
# SNR for speech-us-gov-0016.wav: 0.69 dB
# SNR for speech-us-gov-0017.wav: -0.03 dB
# SNR for speech-us-gov-0018.wav: -0.38 dB
# SNR for speech-us-gov-0019.wav: -0.38 dB
# SNR for speech-us-gov-0020.wav: 0.91 dB
# SNR for speech-us-gov-0021.wav: -0.56 dB
# SNR for speech-us-gov-0022.wav: -0.89 dB
# SNR for speech-us-gov-0023.wav: -0.34 dB
# SNR for speech-us-gov-0024.wav: -0.55 dB
# SNR for speech-us-gov-0025.wav: -0.27 dB
# SNR for speech-us-gov-0026.wav: -0.13 dB
# SNR for speech-us-gov-0027.wav: 0.03 dB
# SNR for speech-us-gov-0028.wav: -0.45 dB
# SNR for speech-us-gov-0029.wav: -0.55 dB
# SNR for speech-us-gov-0030.wav: 0.23 dB
# SNR for speech-us-gov-0031.wav: -0.03 dB
# SNR for speech-us-gov-0032.wav: -0.51 dB
# SNR for speech-us-gov-0033.wav: 0.01 dB
# SNR for speech-us-gov-0034.wav: -0.35 dB
# SNR for speech-us-gov-0035.wav: 0.02 dB
# SNR for speech-us-gov-0036.wav: -0.19 dB
# SNR for speech-us-gov-0037.wav: -0.47 dB
# SNR for speech-us-gov-0038.wav: -0.56 dB
# SNR for speech-us-gov-0039.wav: -0.30 dB
# SNR for speech-us-gov-0040.wav: -0.44 dB
# SNR for speech-us-gov-0041.wav: -0.40 dB
# SNR for speech-us-gov-0042.wav: -0.82 dB
# SNR for speech-us-gov-0043.wav: -1.06 dB
# SNR for speech-us-gov-0044.wav: -0.68 dB
# SNR for speech-us-gov-0045.wav: -0.83 dB
# SNR for speech-us-gov-0046.wav: 0.37 dB
# SNR for speech-us-gov-0047.wav: 0.20 dB
# SNR for speech-us-gov-0048.wav: -0.05 dB
# SNR for speech-us-gov-0049.wav: -0.61 dB
# SNR for speech-us-gov-0050.wav: -0.57 dB
# SNR for speech-us-gov-0051.wav: -0.99 dB
# SNR for speech-us-gov-0052.wav: -0.59 dB
# SNR for speech-us-gov-0053.wav: -0.60 dB
# SNR for speech-us-gov-0054.wav: -0.74 dB
# SNR for speech-us-gov-0055.wav: -0.68 dB
# SNR for speech-us-gov-0056.wav: -1.04 dB
# SNR for speech-us-gov-0057.wav: -0.98 dB
# SNR for speech-us-gov-0058.wav: -0.74 dB
# SNR for speech-us-gov-0059.wav: 0.20 dB
# SNR for speech-us-gov-0060.wav: 0.10 dB
# SNR for speech-us-gov-0061.wav: -0.28 dB
# SNR for speech-us-gov-0062.wav: -0.24 dB
# SNR for speech-us-gov-0063.wav: -0.85 dB
# SNR for speech-us-gov-0064.wav: -0.73 dB
# SNR for speech-us-gov-0065.wav: -0.78 dB
# SNR for speech-us-gov-0066.wav: -0.70 dB
# SNR for speech-us-gov-0067.wav: -0.60 dB
# SNR for speech-us-gov-0068.wav: -0.23 dB
# SNR for speech-us-gov-0069.wav: -0.41 dB
# SNR for speech-us-gov-0070.wav: -0.08 dB
# SNR for speech-us-gov-0071.wav: -0.48 dB
# SNR for speech-us-gov-0072.wav: -0.40 dB
# SNR for speech-us-gov-0073.wav: -0.48 dB
# SNR for speech-us-gov-0074.wav: -0.44 dB
# SNR for speech-us-gov-0075.wav: -0.34 dB
# SNR for speech-us-gov-0076.wav: -0.42 dB
# SNR for speech-us-gov-0077.wav: -0.47 dB
# SNR for speech-us-gov-0078.wav: -0.30 dB
# SNR for speech-us-gov-0079.wav: -0.37 dB
# SNR for speech-us-gov-0080.wav: -0.96 dB
# SNR for speech-us-gov-0081.wav: -0.32 dB
# SNR for speech-us-gov-0082.wav: -0.32 dB
# SNR for speech-us-gov-0083.wav: -0.18 dB
# SNR for speech-us-gov-0084.wav: 0.28 dB
# SNR for speech-us-gov-0085.wav: 0.49 dB
# SNR for speech-us-gov-0086.wav: 0.47 dB
# SNR for speech-us-gov-0087.wav: 0.31 dB
# SNR for speech-us-gov-0088.wav: 0.50 dB
# SNR for speech-us-gov-0089.wav: 0.03 dB
# SNR for speech-us-gov-0090.wav: -0.26 dB
# SNR for speech-us-gov-0091.wav: -0.03 dB
# SNR for speech-us-gov-0092.wav: 1.02 dB
# SNR for speech-us-gov-0093.wav: 0.55 dB
# SNR for speech-us-gov-0094.wav: 0.53 dB
# SNR for speech-us-gov-0095.wav: 0.18 dB
# SNR for speech-us-gov-0096.wav: 0.64 dB
# SNR for speech-us-gov-0097.wav: 0.09 dB
# SNR for speech-us-gov-0098.wav: 0.16 dB
# SNR for speech-us-gov-0099.wav: -0.56 dB
# SNR for speech-us-gov-0100.wav: 0.56 dB
# SNR for speech-us-gov-0101.wav: 0.65 dB
# SNR for speech-us-gov-0102.wav: 0.46 dB
# SNR for speech-us-gov-0103.wav: -0.15 dB
# SNR for speech-us-gov-0104.wav: 1.07 dB
# SNR for speech-us-gov-0105.wav: 0.34 dB
# SNR for speech-us-gov-0106.wav: 0.30 dB
# SNR for speech-us-gov-0107.wav: 0.94 dB
# SNR for speech-us-gov-0108.wav: 0.45 dB
# SNR for speech-us-gov-0109.wav: 0.65 dB
# SNR for speech-us-gov-0110.wav: 0.67 dB
# SNR for speech-us-gov-0111.wav: 0.49 dB
# SNR for speech-us-gov-0112.wav: -0.09 dB
# SNR for speech-us-gov-0113.wav: 0.41 dB
# SNR for speech-us-gov-0114.wav: 0.07 dB
# SNR for speech-us-gov-0115.wav: 0.40 dB
# SNR for speech-us-gov-0116.wav: -0.06 dB
# SNR for speech-us-gov-0117.wav: 0.48 dB
# SNR for speech-us-gov-0118.wav: -0.05 dB
# SNR for speech-us-gov-0119.wav: 0.12 dB
# SNR for speech-us-gov-0120.wav: 0.05 dB
# SNR for speech-us-gov-0121.wav: 0.41 dB
# SNR for speech-us-gov-0122.wav: -0.26 dB
# SNR for speech-us-gov-0123.wav: 0.20 dB
# SNR for speech-us-gov-0124.wav: -0.01 dB
# SNR for speech-us-gov-0125.wav: -0.74 dB
# SNR for speech-us-gov-0126.wav: 0.27 dB
# SNR for speech-us-gov-0127.wav: 0.01 dB
# SNR for speech-us-gov-0128.wav: -0.44 dB
# SNR for speech-us-gov-0129.wav: 0.02 dB
# SNR for speech-us-gov-0130.wav: 0.16 dB
# SNR for speech-us-gov-0131.wav: 1.68 dB
# SNR for speech-us-gov-0132.wav: 1.72 dB
# SNR for speech-us-gov-0133.wav: 1.41 dB
# SNR for speech-us-gov-0134.wav: 1.06 dB
# SNR for speech-us-gov-0135.wav: 1.30 dB
# SNR for speech-us-gov-0136.wav: 1.54 dB
# SNR for speech-us-gov-0137.wav: 1.64 dB
# SNR for speech-us-gov-0138.wav: 1.80 dB
# SNR for speech-us-gov-0139.wav: 1.77 dB
# SNR for speech-us-gov-0140.wav: 1.47 dB
# SNR for speech-us-gov-0141.wav: 0.05 dB
# SNR for speech-us-gov-0142.wav: 0.91 dB
# SNR for speech-us-gov-0143.wav: -0.91 dB
# SNR for speech-us-gov-0144.wav: -0.24 dB
# SNR for speech-us-gov-0145.wav: -0.30 dB
# SNR for speech-us-gov-0146.wav: -0.38 dB
# SNR for speech-us-gov-0147.wav: 0.42 dB
# SNR for speech-us-gov-0148.wav: -0.10 dB
# SNR for speech-us-gov-0149.wav: -0.12 dB
#
# ✅ Average SNR for compressed dataset (first 150 files): -0.06 dB

# %%
#analyzing using SNR,SDR,STOI and PESQ for us-gov data of 3kbps


import os
import librosa
import numpy as np
from pesq import pesq
from pystoi import stoi
from mir_eval.separation import bss_eval_sources

# === Constants ===
SAMPLE_RATE = 16000
DURATION = 30
TARGET_SAMPLES = SAMPLE_RATE * DURATION

# === Evaluation Functions ===
def fix_length(audio, target_len):
    if len(audio) > target_len:
        return audio[:target_len]
    return np.pad(audio, (0, target_len - len(audio)))

def snr(original, compressed):
    min_len = min(len(original), len(compressed))
    original = original[:min_len]
    compressed = compressed[:min_len]
    noise = original - compressed
    eps = 1e-10
    return 10 * np.log10(np.sum(original ** 2) / (np.sum(noise ** 2) + eps))

# === Paths ===
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/us-gov"
COMPRESSED_PATH = "/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps"

# === Metric Storage ===
snr_values, sdr_values, stoi_values, pesq_values = [], [], [], []

# === Evaluation Loop ===
for root, _, files in os.walk(ORIGINAL_PATH):
    for file in sorted(files):
        if file.endswith(".wav"):
            original_file = os.path.join(root, file)
            compressed_file = os.path.join(COMPRESSED_PATH, file.replace(".wav", ".opus"))

            try:
                orig_audio, _ = librosa.load(original_file, sr=SAMPLE_RATE)
                comp_audio, _ = librosa.load(compressed_file, sr=SAMPLE_RATE)

                orig_audio = fix_length(orig_audio, TARGET_SAMPLES)
                comp_audio = fix_length(comp_audio, TARGET_SAMPLES)

                # SNR
                snr_values.append(snr(orig_audio, comp_audio))

                # SDR
                sdr, _, _, _ = bss_eval_sources(orig_audio[None, :], comp_audio[None, :])
                sdr_values.append(sdr[0])

                # STOI
                stoi_values.append(stoi(orig_audio, comp_audio, SAMPLE_RATE, extended=False))

                # PESQ
                pesq_score = pesq(SAMPLE_RATE, orig_audio, comp_audio, 'wb')
                pesq_values.append(pesq_score)

                print(f"✅ {file}: SNR={snr_values[-1]:.2f}, SDR={sdr[0]:.2f}, STOI={stoi_values[-1]:.3f}, PESQ={pesq_score:.3f}")

            except Exception as e:
                print(f"⚠️ Error processing {file}: {e}")

# === Print Averages ===
if snr_values:
    print("\n📊 Compressed Audio Evaluation (vs Original):")
    print(f"✅ Avg SNR :  {np.mean(snr_values):.2f} dB")
    print(f"✅ Avg SDR :  {np.mean(sdr_values):.2f} dB")
    print(f"✅ Avg STOI:  {np.mean(stoi_values):.3f}")
    print(f"✅ Avg PESQ:  {np.mean(pesq_values):.3f}")
else:
    print("\n⚠ No valid files processed for metric calculation.")
# Out:
# <ipython-input-5-79c02247bad7>:52: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(orig_audio[None, :], comp_audio[None, :])
# ✅ speech-us-gov-0000.wav: SNR=1.38, SDR=-0.73, STOI=0.587, PESQ=1.534
# ✅ speech-us-gov-0001.wav: SNR=1.10, SDR=-1.52, STOI=0.554, PESQ=1.306
# ✅ speech-us-gov-0002.wav: SNR=1.03, SDR=-2.70, STOI=0.539, PESQ=1.465
# ✅ speech-us-gov-0003.wav: SNR=-0.33, SDR=-5.64, STOI=0.452, PESQ=1.299
# ✅ speech-us-gov-0004.wav: SNR=-0.29, SDR=-6.55, STOI=0.386, PESQ=1.210
# ✅ speech-us-gov-0005.wav: SNR=-2.82, SDR=-10.94, STOI=0.480, PESQ=1.291
# ✅ speech-us-gov-0006.wav: SNR=-1.30, SDR=-11.92, STOI=0.502, PESQ=1.286
# ✅ speech-us-gov-0007.wav: SNR=-1.94, SDR=-11.59, STOI=0.527, PESQ=1.252
# ✅ speech-us-gov-0008.wav: SNR=-1.24, SDR=-10.07, STOI=0.524, PESQ=1.301
# ✅ speech-us-gov-0009.wav: SNR=0.09, SDR=-7.19, STOI=0.581, PESQ=1.201
# ✅ speech-us-gov-0010.wav: SNR=-0.25, SDR=-7.15, STOI=0.572, PESQ=1.256
# ✅ speech-us-gov-0011.wav: SNR=-1.03, SDR=-9.26, STOI=0.593, PESQ=1.208
# ✅ speech-us-gov-0012.wav: SNR=-0.54, SDR=-9.11, STOI=0.582, PESQ=1.228
# ✅ speech-us-gov-0013.wav: SNR=-0.38, SDR=-8.26, STOI=0.542, PESQ=1.256
# ✅ speech-us-gov-0014.wav: SNR=-2.14, SDR=-12.01, STOI=0.428, PESQ=1.236
# ✅ speech-us-gov-0015.wav: SNR=-0.04, SDR=-4.78, STOI=0.696, PESQ=1.683
# ✅ speech-us-gov-0016.wav: SNR=-0.78, SDR=-6.50, STOI=0.657, PESQ=1.520
# ✅ speech-us-gov-0017.wav: SNR=0.77, SDR=-2.91, STOI=0.707, PESQ=1.627
# ✅ speech-us-gov-0018.wav: SNR=-0.04, SDR=-5.68, STOI=0.646, PESQ=1.575
# ✅ speech-us-gov-0019.wav: SNR=-0.30, SDR=-4.71, STOI=0.653, PESQ=1.632
# ✅ speech-us-gov-0020.wav: SNR=-0.35, SDR=-5.91, STOI=0.731, PESQ=1.537
# ✅ speech-us-gov-0021.wav: SNR=0.11, SDR=-5.01, STOI=0.708, PESQ=1.688
# ✅ speech-us-gov-0022.wav: SNR=-1.16, SDR=-7.03, STOI=0.679, PESQ=1.598
# ✅ speech-us-gov-0023.wav: SNR=-0.53, SDR=-5.38, STOI=0.664, PESQ=1.563
# ✅ speech-us-gov-0024.wav: SNR=-0.54, SDR=-6.33, STOI=0.674, PESQ=1.701
# ✅ speech-us-gov-0025.wav: SNR=-0.92, SDR=-6.70, STOI=0.669, PESQ=1.572
# ✅ speech-us-gov-0026.wav: SNR=-1.28, SDR=-5.41, STOI=0.650, PESQ=1.696
# ✅ speech-us-gov-0027.wav: SNR=-0.02, SDR=-4.59, STOI=0.677, PESQ=1.598
# ✅ speech-us-gov-0028.wav: SNR=-0.43, SDR=-3.21, STOI=0.668, PESQ=1.598
# ✅ speech-us-gov-0029.wav: SNR=-0.65, SDR=-5.70, STOI=0.698, PESQ=1.490
# ✅ speech-us-gov-0030.wav: SNR=-0.68, SDR=-7.29, STOI=0.671, PESQ=1.567
# ✅ speech-us-gov-0031.wav: SNR=-1.19, SDR=-7.18, STOI=0.661, PESQ=1.610
# ✅ speech-us-gov-0032.wav: SNR=-1.06, SDR=-6.39, STOI=0.688, PESQ=1.766
# ✅ speech-us-gov-0033.wav: SNR=-0.01, SDR=-5.72, STOI=0.678, PESQ=1.708
# ✅ speech-us-gov-0034.wav: SNR=-0.39, SDR=-3.65, STOI=0.764, PESQ=1.908
# ✅ speech-us-gov-0035.wav: SNR=-0.21, SDR=-5.41, STOI=0.661, PESQ=1.606
# ✅ speech-us-gov-0036.wav: SNR=0.47, SDR=-3.40, STOI=0.706, PESQ=1.590
# ✅ speech-us-gov-0037.wav: SNR=-0.83, SDR=-6.31, STOI=0.696, PESQ=1.743
# ✅ speech-us-gov-0038.wav: SNR=-0.68, SDR=-5.69, STOI=0.716, PESQ=1.733
# ✅ speech-us-gov-0039.wav: SNR=-0.04, SDR=-4.11, STOI=0.712, PESQ=1.553
# ✅ speech-us-gov-0040.wav: SNR=-0.66, SDR=-6.05, STOI=0.668, PESQ=1.641
# ✅ speech-us-gov-0041.wav: SNR=-0.20, SDR=-5.31, STOI=0.684, PESQ=1.523
# ✅ speech-us-gov-0042.wav: SNR=-0.73, SDR=-6.44, STOI=0.668, PESQ=1.572
# ✅ speech-us-gov-0043.wav: SNR=-1.09, SDR=-7.28, STOI=0.704, PESQ=1.628
# ✅ speech-us-gov-0044.wav: SNR=-0.69, SDR=-5.95, STOI=0.670, PESQ=1.616
# ✅ speech-us-gov-0045.wav: SNR=-0.62, SDR=-6.94, STOI=0.689, PESQ=1.499
# ✅ speech-us-gov-0046.wav: SNR=-0.67, SDR=-6.65, STOI=0.666, PESQ=1.459
# ✅ speech-us-gov-0047.wav: SNR=0.60, SDR=-4.51, STOI=0.737, PESQ=1.650
# ✅ speech-us-gov-0048.wav: SNR=0.06, SDR=-5.08, STOI=0.697, PESQ=1.746
# ✅ speech-us-gov-0049.wav: SNR=-0.86, SDR=-6.05, STOI=0.641, PESQ=1.608
# ✅ speech-us-gov-0050.wav: SNR=-0.10, SDR=-4.56, STOI=0.658, PESQ=1.562
# ✅ speech-us-gov-0051.wav: SNR=-1.18, SDR=-5.45, STOI=0.733, PESQ=1.718
# ✅ speech-us-gov-0052.wav: SNR=-1.48, SDR=-5.10, STOI=0.722, PESQ=1.704
# ✅ speech-us-gov-0053.wav: SNR=-1.09, SDR=-7.57, STOI=0.692, PESQ=1.681
# ✅ speech-us-gov-0054.wav: SNR=-1.54, SDR=-6.15, STOI=0.705, PESQ=1.626
# ✅ speech-us-gov-0055.wav: SNR=-0.06, SDR=-4.19, STOI=0.707, PESQ=1.660
# ✅ speech-us-gov-0056.wav: SNR=-1.74, SDR=-5.90, STOI=0.721, PESQ=1.731
# ✅ speech-us-gov-0057.wav: SNR=-1.21, SDR=-5.96, STOI=0.716, PESQ=1.593
# ✅ speech-us-gov-0058.wav: SNR=-0.17, SDR=-5.19, STOI=0.709, PESQ=1.718
# ✅ speech-us-gov-0059.wav: SNR=-0.24, SDR=-5.27, STOI=0.689, PESQ=1.689
# ✅ speech-us-gov-0060.wav: SNR=0.29, SDR=-3.57, STOI=0.687, PESQ=1.654
# ✅ speech-us-gov-0061.wav: SNR=-0.74, SDR=-5.51, STOI=0.673, PESQ=1.505
# ✅ speech-us-gov-0062.wav: SNR=-0.04, SDR=-4.97, STOI=0.683, PESQ=1.619
# ✅ speech-us-gov-0063.wav: SNR=-0.76, SDR=-6.43, STOI=0.687, PESQ=1.663
# ✅ speech-us-gov-0064.wav: SNR=-0.67, SDR=-6.74, STOI=0.682, PESQ=1.541
# ✅ speech-us-gov-0065.wav: SNR=-1.07, SDR=-6.52, STOI=0.693, PESQ=1.695
# ✅ speech-us-gov-0066.wav: SNR=-0.97, SDR=-5.76, STOI=0.721, PESQ=1.566
# ✅ speech-us-gov-0067.wav: SNR=0.10, SDR=-4.32, STOI=0.737, PESQ=1.597
# ✅ speech-us-gov-0068.wav: SNR=0.09, SDR=-4.79, STOI=0.700, PESQ=1.612
# ✅ speech-us-gov-0069.wav: SNR=-0.67, SDR=-3.71, STOI=0.747, PESQ=1.846
# ✅ speech-us-gov-0070.wav: SNR=-0.46, SDR=-6.42, STOI=0.677, PESQ=1.660
# ✅ speech-us-gov-0071.wav: SNR=-0.24, SDR=-3.85, STOI=0.693, PESQ=1.634
# ✅ speech-us-gov-0072.wav: SNR=0.31, SDR=-3.80, STOI=0.701, PESQ=1.552
# ✅ speech-us-gov-0073.wav: SNR=-1.15, SDR=-7.58, STOI=0.656, PESQ=1.472
# ✅ speech-us-gov-0074.wav: SNR=-0.68, SDR=-7.07, STOI=0.667, PESQ=1.621
# ✅ speech-us-gov-0075.wav: SNR=-0.58, SDR=-4.49, STOI=0.732, PESQ=1.690
# ✅ speech-us-gov-0076.wav: SNR=-0.78, SDR=-6.11, STOI=0.685, PESQ=1.601
# ✅ speech-us-gov-0077.wav: SNR=-0.21, SDR=-4.10, STOI=0.704, PESQ=1.665
# ✅ speech-us-gov-0078.wav: SNR=-0.25, SDR=-3.84, STOI=0.684, PESQ=1.699
# ✅ speech-us-gov-0079.wav: SNR=-0.00, SDR=-4.12, STOI=0.684, PESQ=1.635
# ✅ speech-us-gov-0080.wav: SNR=-0.91, SDR=-7.18, STOI=0.717, PESQ=1.587
# ✅ speech-us-gov-0081.wav: SNR=-0.86, SDR=-6.97, STOI=0.675, PESQ=1.539
# ✅ speech-us-gov-0082.wav: SNR=-0.14, SDR=-3.82, STOI=0.698, PESQ=1.697
# ✅ speech-us-gov-0083.wav: SNR=-0.58, SDR=-5.82, STOI=0.707, PESQ=1.782
# ✅ speech-us-gov-0084.wav: SNR=-1.60, SDR=-6.71, STOI=0.668, PESQ=1.636
# ✅ speech-us-gov-0085.wav: SNR=1.38, SDR=-1.29, STOI=0.681, PESQ=1.665
# ✅ speech-us-gov-0086.wav: SNR=0.73, SDR=-3.86, STOI=0.678, PESQ=1.703
# ✅ speech-us-gov-0087.wav: SNR=-0.24, SDR=-4.44, STOI=0.681, PESQ=1.598
# ✅ speech-us-gov-0088.wav: SNR=0.04, SDR=-3.66, STOI=0.691, PESQ=1.601
# ✅ speech-us-gov-0089.wav: SNR=-0.14, SDR=-5.58, STOI=0.649, PESQ=1.658
# ✅ speech-us-gov-0090.wav: SNR=0.34, SDR=-5.01, STOI=0.713, PESQ=1.635
# ✅ speech-us-gov-0091.wav: SNR=-0.47, SDR=-5.41, STOI=0.682, PESQ=1.634
# ✅ speech-us-gov-0092.wav: SNR=0.80, SDR=-4.45, STOI=0.618, PESQ=1.418
# ✅ speech-us-gov-0093.wav: SNR=0.41, SDR=-5.42, STOI=0.609, PESQ=1.426
# ✅ speech-us-gov-0094.wav: SNR=0.19, SDR=-7.10, STOI=0.608, PESQ=1.344
# ✅ speech-us-gov-0095.wav: SNR=0.39, SDR=-5.62, STOI=0.641, PESQ=1.737
# ✅ speech-us-gov-0096.wav: SNR=-0.31, SDR=-7.52, STOI=0.564, PESQ=1.366
# ✅ speech-us-gov-0097.wav: SNR=0.31, SDR=-4.66, STOI=0.574, PESQ=2.154
# ✅ speech-us-gov-0098.wav: SNR=0.12, SDR=-5.82, STOI=0.648, PESQ=1.566
# ✅ speech-us-gov-0099.wav: SNR=-0.40, SDR=-8.51, STOI=0.611, PESQ=1.337
# ✅ speech-us-gov-0100.wav: SNR=0.50, SDR=-5.21, STOI=0.615, PESQ=1.474
# ✅ speech-us-gov-0101.wav: SNR=0.45, SDR=-5.34, STOI=0.621, PESQ=1.417
# ✅ speech-us-gov-0102.wav: SNR=-0.02, SDR=-7.01, STOI=0.620, PESQ=1.398
# ✅ speech-us-gov-0103.wav: SNR=-0.21, SDR=-7.04, STOI=0.588, PESQ=1.420
# ✅ speech-us-gov-0104.wav: SNR=0.96, SDR=-3.17, STOI=0.691, PESQ=1.413
# ✅ speech-us-gov-0105.wav: SNR=0.39, SDR=-5.47, STOI=0.673, PESQ=1.435
# ✅ speech-us-gov-0106.wav: SNR=0.12, SDR=-5.14, STOI=0.607, PESQ=1.294
# ✅ speech-us-gov-0107.wav: SNR=1.04, SDR=-3.99, STOI=0.670, PESQ=1.367
# ✅ speech-us-gov-0108.wav: SNR=0.66, SDR=-4.46, STOI=0.671, PESQ=1.538
# ✅ speech-us-gov-0109.wav: SNR=0.65, SDR=-5.09, STOI=0.681, PESQ=1.354
# ✅ speech-us-gov-0110.wav: SNR=-0.22, SDR=-7.51, STOI=0.652, PESQ=1.308
# ✅ speech-us-gov-0111.wav: SNR=0.40, SDR=-5.08, STOI=0.677, PESQ=1.443
# ✅ speech-us-gov-0112.wav: SNR=-1.77, SDR=-12.39, STOI=0.554, PESQ=1.287
# ✅ speech-us-gov-0113.wav: SNR=0.42, SDR=-6.55, STOI=0.486, PESQ=1.233
# ✅ speech-us-gov-0114.wav: SNR=0.19, SDR=-6.97, STOI=0.638, PESQ=1.283
# ✅ speech-us-gov-0115.wav: SNR=-0.02, SDR=-7.37, STOI=0.558, PESQ=1.267
# ✅ speech-us-gov-0116.wav: SNR=-0.44, SDR=-8.50, STOI=0.622, PESQ=1.246
# ✅ speech-us-gov-0117.wav: SNR=1.03, SDR=-4.14, STOI=0.659, PESQ=1.353
# ✅ speech-us-gov-0118.wav: SNR=-0.36, SDR=-8.06, STOI=0.499, PESQ=1.330
# ✅ speech-us-gov-0119.wav: SNR=-0.16, SDR=-8.89, STOI=0.545, PESQ=1.237
# ✅ speech-us-gov-0120.wav: SNR=-0.49, SDR=-10.42, STOI=0.546, PESQ=1.260
# ✅ speech-us-gov-0121.wav: SNR=-0.25, SDR=-8.84, STOI=0.601, PESQ=1.305
# ✅ speech-us-gov-0122.wav: SNR=0.14, SDR=-7.13, STOI=0.556, PESQ=1.259
# ✅ speech-us-gov-0123.wav: SNR=-0.21, SDR=-8.03, STOI=0.553, PESQ=1.176
# ✅ speech-us-gov-0124.wav: SNR=0.17, SDR=-7.15, STOI=0.557, PESQ=1.295
# ✅ speech-us-gov-0125.wav: SNR=-1.03, SDR=-8.69, STOI=0.574, PESQ=1.399
# ✅ speech-us-gov-0126.wav: SNR=0.45, SDR=-5.47, STOI=0.650, PESQ=1.374
# ✅ speech-us-gov-0127.wav: SNR=-0.13, SDR=-7.40, STOI=0.628, PESQ=1.311
# ✅ speech-us-gov-0128.wav: SNR=-0.67, SDR=-9.22, STOI=0.609, PESQ=1.261
# ✅ speech-us-gov-0129.wav: SNR=0.02, SDR=-7.31, STOI=0.633, PESQ=1.338
# ✅ speech-us-gov-0130.wav: SNR=0.03, SDR=-7.64, STOI=0.639, PESQ=1.344
# ✅ speech-us-gov-0131.wav: SNR=1.30, SDR=-3.05, STOI=0.733, PESQ=1.572
# ✅ speech-us-gov-0132.wav: SNR=1.46, SDR=-2.45, STOI=0.771, PESQ=1.358
# ✅ speech-us-gov-0133.wav: SNR=2.26, SDR=-0.76, STOI=0.746, PESQ=1.423
# ✅ speech-us-gov-0134.wav: SNR=0.89, SDR=-4.02, STOI=0.747, PESQ=1.441
# ✅ speech-us-gov-0135.wav: SNR=0.89, SDR=-4.07, STOI=0.760, PESQ=1.422
# ✅ speech-us-gov-0136.wav: SNR=1.37, SDR=-2.83, STOI=0.747, PESQ=1.475
# ✅ speech-us-gov-0137.wav: SNR=1.40, SDR=-2.88, STOI=0.723, PESQ=1.402
# ✅ speech-us-gov-0138.wav: SNR=2.27, SDR=-0.94, STOI=0.771, PESQ=1.601
# ✅ speech-us-gov-0139.wav: SNR=2.27, SDR=-1.00, STOI=0.777, PESQ=1.400
# ✅ speech-us-gov-0140.wav: SNR=1.64, SDR=-2.48, STOI=0.748, PESQ=1.436
# ✅ speech-us-gov-0141.wav: SNR=1.30, SDR=-2.48, STOI=0.635, PESQ=1.258
# ✅ speech-us-gov-0142.wav: SNR=-0.42, SDR=-5.84, STOI=0.623, PESQ=1.276
# ✅ speech-us-gov-0143.wav: SNR=-1.35, SDR=-10.37, STOI=0.622, PESQ=1.304
# ✅ speech-us-gov-0144.wav: SNR=-1.61, SDR=-8.65, STOI=0.605, PESQ=1.322
# ✅ speech-us-gov-0145.wav: SNR=0.19, SDR=-5.35, STOI=0.703, PESQ=1.248
# ✅ speech-us-gov-0146.wav: SNR=-0.78, SDR=-9.03, STOI=0.563, PESQ=1.282
# ✅ speech-us-gov-0147.wav: SNR=-0.18, SDR=-5.89, STOI=0.635, PESQ=1.368
# ✅ speech-us-gov-0148.wav: SNR=-0.64, SDR=-6.19, STOI=0.570, PESQ=1.308
# ✅ speech-us-gov-0149.wav: SNR=-0.26, SDR=-7.75, STOI=0.589, PESQ=1.249
# <ipython-input-5-79c02247bad7>:43: UserWarning: PySoundFile failed. Trying audioread instead.
#   comp_audio, _ = librosa.load(compressed_file, sr=SAMPLE_RATE)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ⚠️ Error processing speech-us-gov-0150.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0150.opus'
# ⚠️ Error processing speech-us-gov-0151.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0151.opus'
# ⚠️ Error processing speech-us-gov-0152.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0152.opus'
# ⚠️ Error processing speech-us-gov-0153.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0153.opus'
# ⚠️ Error processing speech-us-gov-0154.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0154.opus'
# ⚠️ Error processing speech-us-gov-0155.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0155.opus'
# ⚠️ Error processing speech-us-gov-0156.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0156.opus'
# ⚠️ Error processing speech-us-gov-0157.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0157.opus'
# ⚠️ Error processing speech-us-gov-0158.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0158.opus'
# ⚠️ Error processing speech-us-gov-0159.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0159.opus'
# ⚠️ Error processing speech-us-gov-0160.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0160.opus'
# ⚠️ Error processing speech-us-gov-0161.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0161.opus'
# ⚠️ Error processing speech-us-gov-0162.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0162.opus'
# ⚠️ Error processing speech-us-gov-0163.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0163.opus'
# ⚠️ Error processing speech-us-gov-0164.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0164.opus'
# ⚠️ Error processing speech-us-gov-0165.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0165.opus'
# ⚠️ Error processing speech-us-gov-0166.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0166.opus'
# ⚠️ Error processing speech-us-gov-0167.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0167.opus'
# ⚠️ Error processing speech-us-gov-0168.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0168.opus'
# ⚠️ Error processing speech-us-gov-0169.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0169.opus'
# ⚠️ Error processing speech-us-gov-0170.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0170.opus'
# ⚠️ Error processing speech-us-gov-0171.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0171.opus'
# ⚠️ Error processing speech-us-gov-0172.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0172.opus'
# ⚠️ Error processing speech-us-gov-0173.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0173.opus'
# ⚠️ Error processing speech-us-gov-0174.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0174.opus'
# ⚠️ Error processing speech-us-gov-0175.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0175.opus'
# ⚠️ Error processing speech-us-gov-0176.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0176.opus'
# ⚠️ Error processing speech-us-gov-0177.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0177.opus'
# ⚠️ Error processing speech-us-gov-0178.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0178.opus'
# ⚠️ Error processing speech-us-gov-0179.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0179.opus'
# ⚠️ Error processing speech-us-gov-0180.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0180.opus'
# ⚠️ Error processing speech-us-gov-0181.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0181.opus'
# ⚠️ Error processing speech-us-gov-0182.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0182.opus'
# ⚠️ Error processing speech-us-gov-0183.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0183.opus'
# ⚠️ Error processing speech-us-gov-0184.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0184.opus'
# ⚠️ Error processing speech-us-gov-0185.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0185.opus'
# ⚠️ Error processing speech-us-gov-0186.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0186.opus'
# ⚠️ Error processing speech-us-gov-0187.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0187.opus'
# ⚠️ Error processing speech-us-gov-0188.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0188.opus'
# ⚠️ Error processing speech-us-gov-0189.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0189.opus'
# ⚠️ Error processing speech-us-gov-0190.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0190.opus'
# ⚠️ Error processing speech-us-gov-0191.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0191.opus'
# ⚠️ Error processing speech-us-gov-0192.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0192.opus'
# ⚠️ Error processing speech-us-gov-0193.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0193.opus'
# ⚠️ Error processing speech-us-gov-0194.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0194.opus'
# ⚠️ Error processing speech-us-gov-0195.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0195.opus'
# ⚠️ Error processing speech-us-gov-0196.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0196.opus'
# ⚠️ Error processing speech-us-gov-0197.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0197.opus'
# ⚠️ Error processing speech-us-gov-0198.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0198.opus'
# ⚠️ Error processing speech-us-gov-0199.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0199.opus'
# ⚠️ Error processing speech-us-gov-0200.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0200.opus'
# ⚠️ Error processing speech-us-gov-0201.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0201.opus'
# ⚠️ Error processing speech-us-gov-0202.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0202.opus'
# ⚠️ Error processing speech-us-gov-0203.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0203.opus'
# ⚠️ Error processing speech-us-gov-0204.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0204.opus'
# ⚠️ Error processing speech-us-gov-0205.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0205.opus'
# ⚠️ Error processing speech-us-gov-0206.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0206.opus'
# ⚠️ Error processing speech-us-gov-0207.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0207.opus'
# ⚠️ Error processing speech-us-gov-0208.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0208.opus'
# ⚠️ Error processing speech-us-gov-0209.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0209.opus'
# ⚠️ Error processing speech-us-gov-0210.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0210.opus'
# ⚠️ Error processing speech-us-gov-0211.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0211.opus'
# ⚠️ Error processing speech-us-gov-0212.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0212.opus'
# ⚠️ Error processing speech-us-gov-0213.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0213.opus'
# ⚠️ Error processing speech-us-gov-0214.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0214.opus'
# ⚠️ Error processing speech-us-gov-0215.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0215.opus'
# ⚠️ Error processing speech-us-gov-0216.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0216.opus'
# ⚠️ Error processing speech-us-gov-0217.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0217.opus'
# ⚠️ Error processing speech-us-gov-0218.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0218.opus'
# ⚠️ Error processing speech-us-gov-0219.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0219.opus'
# ⚠️ Error processing speech-us-gov-0220.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0220.opus'
# ⚠️ Error processing speech-us-gov-0221.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0221.opus'
# ⚠️ Error processing speech-us-gov-0222.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0222.opus'
# ⚠️ Error processing speech-us-gov-0223.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0223.opus'
# ⚠️ Error processing speech-us-gov-0224.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0224.opus'
# ⚠️ Error processing speech-us-gov-0225.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0225.opus'
# ⚠️ Error processing speech-us-gov-0226.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0226.opus'
# ⚠️ Error processing speech-us-gov-0227.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0227.opus'
# ⚠️ Error processing speech-us-gov-0228.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0228.opus'
# ⚠️ Error processing speech-us-gov-0229.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0229.opus'
# ⚠️ Error processing speech-us-gov-0230.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0230.opus'
# ⚠️ Error processing speech-us-gov-0231.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0231.opus'
# ⚠️ Error processing speech-us-gov-0232.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0232.opus'
# ⚠️ Error processing speech-us-gov-0233.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0233.opus'
# ⚠️ Error processing speech-us-gov-0234.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0234.opus'
# ⚠️ Error processing speech-us-gov-0235.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0235.opus'
# ⚠️ Error processing speech-us-gov-0236.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0236.opus'
# ⚠️ Error processing speech-us-gov-0237.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0237.opus'
# ⚠️ Error processing speech-us-gov-0238.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0238.opus'
# ⚠️ Error processing speech-us-gov-0239.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0239.opus'
# ⚠️ Error processing speech-us-gov-0240.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0240.opus'
# ⚠️ Error processing speech-us-gov-0241.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0241.opus'
# ⚠️ Error processing speech-us-gov-0242.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0242.opus'
# ⚠️ Error processing speech-us-gov-0243.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0243.opus'
# ⚠️ Error processing speech-us-gov-0244.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0244.opus'
# ⚠️ Error processing speech-us-gov-0245.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0245.opus'
# ⚠️ Error processing speech-us-gov-0246.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0246.opus'
# ⚠️ Error processing speech-us-gov-0247.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0247.opus'
# ⚠️ Error processing speech-us-gov-0248.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0248.opus'
# ⚠️ Error processing speech-us-gov-0249.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0249.opus'
# ⚠️ Error processing speech-us-gov-0250.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0250.opus'
# ⚠️ Error processing speech-us-gov-0251.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0251.opus'
# ⚠️ Error processing speech-us-gov-0252.wav: [Errno 2] No such file or directory: '/kaggle/input/compressed-data/compressed_musan/speech/us-gov/usgov_compressed_3kbps/speech-us-gov-0252.opus'
#
# 📊 Compressed Audio Evaluation (vs Original):
# ✅ Avg SNR :  -0.19 dB
# ✅ Avg SDR :  -5.86 dB
# ✅ Avg STOI:  0.652
# ✅ Avg PESQ:  1.500

# %% [markdown]
# # Step 5: Aligning Original and compressed pairs for training the model

# %%
import os
import librosa
import torch
from torch.utils.data import Dataset, DataLoader

# Define paths
ORIGINAL_SPEECH_PATH = "/kaggle/input/musan-data/musan/speech"
COMPRESSED_SPEECH_PATH = "/kaggle/input/compressed-data/compressed_musan/speech"
BITRATES = ["3kbps", "6kbps", "12kbps"]
SUBSETS = ["librivox", "us-gov"]
US_GOV_COMPRESSED_LIMIT = 150  # Only first 150 files are compressed

class SpeechDataset(Dataset):
    def __init__(self, original_path, compressed_path, bitrates, subsets, sr=16000):
        self.original_path = original_path
        self.compressed_path = compressed_path
        self.bitrates = bitrates
        self.subsets = subsets
        self.sr = sr
        self.file_pairs = self._get_file_pairs()
        
        if len(self.file_pairs) == 0:
            raise ValueError("❌ No matching file pairs found! Check your paths.")

    def _get_file_pairs(self):
        file_pairs = []
        for subset in self.subsets:
            subset_path = os.path.join(self.original_path, subset)
            file_list = sorted([f for f in os.listdir(subset_path) if f.endswith(".wav")])

            if subset == "us-gov":
                file_list = file_list[:US_GOV_COMPRESSED_LIMIT]  # Limit to 150 files

            for file in file_list:
                original_file = os.path.join(subset_path, file)

                for bitrate in self.bitrates:
                    if subset == "librivox":
                        compressed_file = os.path.join(
                            self.compressed_path, subset, f"compressed_{bitrate}", subset, file.replace(".wav", ".opus")
                        )
                    elif subset == "us-gov":
                        compressed_file = os.path.join(
                            self.compressed_path, subset, f"usgov_compressed_{bitrate}", file.replace(".wav", ".opus")
                        )

                    if os.path.exists(compressed_file):
                        file_pairs.append((original_file, compressed_file))
                    else:
                        print(f"❌ Missing file: {compressed_file}")  # Debugging output
                
        return file_pairs

    def __len__(self):
        return len(self.file_pairs)

    def __getitem__(self, idx):
        orig_file, comp_file = self.file_pairs[idx]
        orig_audio, _ = librosa.load(orig_file, sr=self.sr)
        comp_audio, _ = librosa.load(comp_file, sr=self.sr)

        # ✅ Ensure correct format (channels, samples) → (1, samples)
        orig_audio = torch.tensor(orig_audio).unsqueeze(0)  # (1, samples)
        comp_audio = torch.tensor(comp_audio).unsqueeze(0)  # (1, samples)

        return orig_audio, comp_audio

# Collate function to pad all audio to the longest sample in the batch
def collate_fn(batch):
    orig_batch, comp_batch = zip(*batch)
    
    max_len = max(max(x.shape[1] for x in orig_batch), max(x.shape[1] for x in comp_batch))
    
    def pad_audio(audio):
        return torch.nn.functional.pad(audio, (0, max_len - audio.shape[1]))

    orig_batch = torch.stack([pad_audio(x) for x in orig_batch])  # (batch, 1, samples)
    comp_batch = torch.stack([pad_audio(x) for x in comp_batch])  # (batch, 1, samples)
    
    return orig_batch, comp_batch

# ✅ Load dataset into DataLoader
dataset = SpeechDataset(ORIGINAL_SPEECH_PATH, COMPRESSED_SPEECH_PATH, BITRATES, SUBSETS)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# ✅ Check dataset loading
for orig, comp in dataloader:
    print(f"✅ After Fix - Original Shape: {orig.shape}, Compressed Shape: {comp.shape}")
    break  # Only check the first batch
# Out:
# ✅ After Fix - Original Shape: torch.Size([4, 1, 9599687]), Compressed Shape: torch.Size([4, 1, 9599687])

# %% [markdown]
# # Step 6 : Model Training using demucs

# %%
# !pip install -q demucs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.9/248.9 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 3.4 MB/s eta 0:00:00
#   Building wheel for demucs (setup.py) ... done
#   Building wheel for julius (setup.py) ... done
#   Building wheel for dora-search (pyproject.toml) ... done
#   Building wheel for treetable (setup.py) ... done

# %%
# !pip install -q demucs
import os
import librosa
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from demucs.hdemucs import HDemucs  # Corrected import

# ✅ Ensure GPU Usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"🔥 Using device: {device}")
# Out:
# 🔥 Using device: cuda

# %%
# Paths
ORIGINAL_SPEECH_PATH = "/kaggle/input/musan-data/musan/speech"
COMPRESSED_SPEECH_PATH = "/kaggle/input/compressed-data/compressed_musan/speech"
BITRATES = ["3kbps", "6kbps", "12kbps"]
SUBSETS = ["librivox", "us-gov"]
SAMPLE_RATE = 16000
DURATION = 30  # 30 seconds
TARGET_SAMPLES = SAMPLE_RATE * DURATION

class SpeechDataset(Dataset):
    def __init__(self, original_path, compressed_path, bitrates, subsets, sr=SAMPLE_RATE):
        self.original_path = original_path
        self.compressed_path = compressed_path
        self.bitrates = bitrates
        self.subsets = subsets
        self.sr = sr
        self.file_pairs = self._get_file_pairs()
        
        if len(self.file_pairs) == 0:
            raise ValueError("❌ No matching file pairs found! Check your paths.")

    def _get_file_pairs(self):
        file_pairs = []
        for subset in self.subsets:
            subset_path = os.path.join(self.original_path, subset)
            file_list = sorted([f for f in os.listdir(subset_path) if f.endswith(".wav")])

            for file in file_list:
                original_file = os.path.join(subset_path, file)

                for bitrate in self.bitrates:
                    compressed_file = os.path.join(
                        self.compressed_path, subset, f"compressed_{bitrate}", subset, file.replace(".wav", ".opus")
                    )

                    if os.path.exists(compressed_file):
                        file_pairs.append((original_file, compressed_file))
                
        return file_pairs

    def _load_audio(self, path):
        audio, _ = librosa.load(path, sr=self.sr, mono=True)
        if len(audio) > TARGET_SAMPLES:
            audio = audio[:TARGET_SAMPLES]
        else:
            audio = F.pad(torch.tensor(audio), (0, TARGET_SAMPLES - len(audio)))
        return audio

    def __len__(self):
        return len(self.file_pairs)

    def __getitem__(self, idx):
        orig_file, comp_file = self.file_pairs[idx]
        orig_audio = self._load_audio(orig_file)
        comp_audio = self._load_audio(comp_file)
        return orig_audio, comp_audio

# %%
import torch

def collate_fn(batch):
    orig_batch, comp_batch = zip(*batch)  # Unpack pairs

    def stereo(audio):
        audio = torch.tensor(audio, dtype=torch.float32)  # ✅ Convert NumPy to Tensor
        return torch.stack([audio, audio], dim=0)  # Duplicate mono signal to stereo

    orig_batch = torch.stack([stereo(x) for x in orig_batch])  # (B, 2, T)
    comp_batch = torch.stack([stereo(x) for x in comp_batch])  # (B, 2, T)

    return orig_batch, comp_batch

# %%
dataset = SpeechDataset(ORIGINAL_SPEECH_PATH, COMPRESSED_SPEECH_PATH, BITRATES, SUBSETS)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

print(f"✅ Loaded {len(dataset)} audio pairs")
# Out:
# ✅ Loaded 519 audio pairs

# %%
model = HDemucs(sources=["speech"]).to(device)  # Load pretrained Demucs
optimizer = optim.Adam(model.parameters(), lr=1e-4)
loss_fn = nn.MSELoss()

# %%
EPOCHS = 10  # Adjust as needed

for epoch in range(EPOCHS):
    total_loss = 0
    model.train()
    
    for orig_wave, comp_wave in dataloader:
        orig_wave, comp_wave = orig_wave.to(device), comp_wave.to(device)

        optimizer.zero_grad()
        enhanced_wave = model(comp_wave)  # Demucs predicts clean audio

        # 🔧 Fix: Match shape with target
        if enhanced_wave.ndim == 4:
            enhanced_wave = enhanced_wave.squeeze(1)  # From (B,1,2,T) → (B,2,T)

        # 🧪 Optional check
        assert enhanced_wave.shape == orig_wave.shape, \
            f"Shape mismatch: got {enhanced_wave.shape}, expected {orig_wave.shape}"

        loss = loss_fn(enhanced_wave, orig_wave)

        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"📢 Epoch {epoch+1}/{EPOCHS}, Loss: {total_loss / len(dataloader):.6f}")
# Out:
# 📢 Epoch 1/10, Loss: 0.002582
# 📢 Epoch 2/10, Loss: 0.002220
# 📢 Epoch 3/10, Loss: 0.002198
# 📢 Epoch 4/10, Loss: 0.002170
# 📢 Epoch 5/10, Loss: 0.002157
# 📢 Epoch 6/10, Loss: 0.002139
# 📢 Epoch 7/10, Loss: 0.002085
# 📢 Epoch 8/10, Loss: 0.002064
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-b1a65d25c239> in <cell line: 3>()
#       5     model.train()
#       6
# ----> 7     for orig_wave, comp_wave in dataloader:
#       8         orig_wave, comp_wave = orig_wave.to(device), comp_wave.to(device)
#       9
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     755     def _next_data(self):
#     756         index = self._next_index()  # may raise StopIteration
# --> 757         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758         if self._pin_memory:
#     759             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-12-df265de4e3e5> in __getitem__(self, idx)
#      53         orig_file, comp_file = self.file_pairs[idx]
#      54         orig_audio = self._load_audio(orig_file)
# ---> 55         comp_audio = self._load_audio(comp_file)
#      56         return orig_audio, comp_audio
#
# <ipython-input-12-df265de4e3e5> in _load_audio(self, path)
#      40
#      41     def _load_audio(self, path):
# ---> 42         audio, _ = librosa.load(path, sr=self.sr, mono=True)
#      43         if len(audio) > TARGET_SAMPLES:
#      44             audio = audio[:TARGET_SAMPLES]
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     174         # Otherwise try soundfile first, and then fall back if necessary
#     175         try:
# --> 176             y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177
#     178         except sf.SoundFileRuntimeError as exc:
#
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py in __soundfile_load(path, offset, duration, dtype)
#     220
#     221         # Load the target number of frames, and transpose to match librosa form
# --> 222         y = sf_desc.read(frames=frame_duration, dtype=dtype, always_2d=False).T
#     223
#     224     return y, sr_native
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in read(self, frames, dtype, always_2d, fill_value, out)
#     893             if frames < 0 or frames > len(out):
#     894                 frames = len(out)
# --> 895         frames = self._array_io('read', out, frames)
#     896         if len(out) > frames:
#     897             if fill_value is None:
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _array_io(self, action, array, frames)
#    1342         assert array.dtype.itemsize == _ffi.sizeof(ctype)
#    1343         cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1344         return self._cdata_io(action, cdata, ctype, frames)
#    1345
#    1346     def _cdata_io(self, action, data, ctype, frames):
#
# /usr/local/lib/python3.10/dist-packages/soundfile.py in _cdata_io(self, action, data, ctype, frames)
#    1351             curr = self.tell()
#    1352         func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
# -> 1353         frames = func(self._file, data, frames)
#    1354         _error_check(self._errorcode)
#    1355         if self.seekable():
#
# KeyboardInterrupt:

# %% [markdown]
# > ## Training was stopped forcefully since it was taking longer than expected to complete 10 epochs

# %%
torch.save(model.state_dict(), "demucs_epoch_8.pth")
print("✅ Model saved successfully!")
# Out:
# ✅ Model saved successfully!

# %% [markdown]
# # Step 7: Reconstructing using the model on the unseen data

# %%
#compressing 150th - 180th file in us-gov folder which was not used for training earlier

import os
from tqdm import tqdm

def compress_files(input_folder, output_folder, bitrate_kbps=6):
    os.makedirs(output_folder, exist_ok=True)
    files = sorted([f for f in os.listdir(input_folder) if f.endswith(".wav")])[150:180]  # Take only 30

    for file in tqdm(files, desc=f"Compressing to {bitrate_kbps}kbps"):
        input_path = os.path.join(input_folder, file)
        output_path = os.path.join(output_folder, file.replace(".wav", ".opus"))

        os.system(f"ffmpeg -y -loglevel error -i '{input_path}' -c:a libopus -b:a {bitrate_kbps}k '{output_path}'")

    return [os.path.join(output_folder, f.replace(".wav", ".opus")) for f in files]

# Define paths
ORIG_UNSEEN_PATH = "/kaggle/input/musan-data/musan/speech/us-gov"
COMPRESSED_TEST_PATH = "./test_compressed/us-gov"

# Run compression
compressed_files = compress_files(ORIG_UNSEEN_PATH, COMPRESSED_TEST_PATH, bitrate_kbps=6)
# Out:
# Compressing to 6kbps: 100%|██████████| 30/30 [03:02<00:00,  6.08s/it]

# %%
#reconstructing using demucs model

import os
import torch
import torchaudio
import torch.nn.functional as F
from torchaudio.transforms import Resample
from tqdm import tqdm
from demucs.hdemucs import HDemucs
import soundfile as sf

# === CONSTANTS ===
SAMPLE_RATE = 16000
DURATION = 30
TARGET_SAMPLES = SAMPLE_RATE * DURATION
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === PATHS ===
COMPRESSED_FOLDER = "/kaggle/working/test_compressed/us-gov"
SAVE_RECONSTRUCTED = "/kaggle/working/reconstructed_usgov_test"
os.makedirs(SAVE_RECONSTRUCTED, exist_ok=True)

# === LOAD MODEL ===
model = HDemucs(sources=["speech"]).to(DEVICE)
model.load_state_dict(torch.load("/kaggle/input/demucs_epoch_8/pytorch/default/1/demucs_epoch_8.pth", map_location=DEVICE))
model.eval()
print("✅ Model loaded.")

# === HELPER FUNCTION ===
def prepare_input(file_path):
    waveform, sr = torchaudio.load(file_path)  # (1, T) for mono
    if sr != SAMPLE_RATE:
        resampler = Resample(sr, SAMPLE_RATE)
        waveform = resampler(waveform)

    waveform = waveform.mean(dim=0)  # Ensure mono
    if waveform.shape[0] > TARGET_SAMPLES:
        waveform = waveform[:TARGET_SAMPLES]
    else:
        waveform = F.pad(waveform, (0, TARGET_SAMPLES - waveform.shape[0]))

    # Convert to stereo (2, T)
    stereo_wave = torch.stack([waveform, waveform], dim=0)
    return stereo_wave.unsqueeze(0).to(DEVICE)  # (1, 2, T)

# === SELECT FILES ===
compressed_files = sorted([
    os.path.join(COMPRESSED_FOLDER, f)
    for f in os.listdir(COMPRESSED_FOLDER)
    if f.endswith(".opus")
])[:30]  # First 30

# === RECONSTRUCT LOOP ===
for comp_path in tqdm(compressed_files, desc="🔊 Reconstructing"):
    input_tensor = prepare_input(comp_path)

    with torch.no_grad():
        output = model(input_tensor)

        # Handle (B,1,2,T) if needed
        if output.ndim == 4:
            output = output.squeeze(1)  # (B, 2, T)

        output = output.squeeze(0).cpu()  # (2, T)

    # Save as (T, 2)
    out_path = os.path.join(
        SAVE_RECONSTRUCTED,
        os.path.basename(comp_path).replace(".opus", "_reconstructed.wav")
    )
    sf.write(out_path, output.permute(1, 0).numpy(), SAMPLE_RATE)

print("✅ Done reconstructing and saving 30 test files.")
# Out:
# <ipython-input-13-e774701600bb>:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("/kaggle/input/demucs_epoch_8/pytorch/default/1/demucs_epoch_8.pth", map_location=DEVICE))
# ✅ Model loaded.
# 🔊 Reconstructing: 100%|██████████| 30/30 [00:56<00:00,  1.88s/it]
# ✅ Done reconstructing and saving 30 test files.

# %%
#zipping the compressed data (prepared for testing ) and reconstructed
#samples from the working directory

import zipfile
import os

def zip_folder(folder_path, zip_path):
    with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, _, files in os.walk(folder_path):
            for file in files:
                full_path = os.path.join(root, file)
                arcname = os.path.relpath(full_path, start=folder_path)
                zipf.write(full_path, arcname=arcname)

# Paths
reconstructed_folder = "/kaggle/working/reconstructed_usgov_test"
compressed_folder = "/kaggle/working/test_compressed"

# Output ZIP paths
reconstructed_zip = "/kaggle/working/reconstructed_usgov_test.zip"
compressed_zip = "/kaggle/working/test_compressed.zip"

# Zip both folders
zip_folder(reconstructed_folder, reconstructed_zip)
zip_folder(compressed_folder, compressed_zip)

print("✅ Both folders zipped and saved:")
print(f"📁 {reconstructed_zip}")
print(f"📁 {compressed_zip}")
# Out:
# ✅ Both folders zipped and saved:
# 📁 /kaggle/working/reconstructed_usgov_test.zip
# 📁 /kaggle/working/test_compressed.zip

# %%
# !pip install pystoi
# !pip install pesq
# Out:
# Collecting pystoi
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from pystoi) (1.13.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->pystoi) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->pystoi) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->pystoi) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->pystoi) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->pystoi) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->pystoi) (2024.2.0)
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Installing collected packages: pystoi
# Successfully installed pystoi-0.4.1
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pesq
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp310-cp310-linux_x86_64.whl size=262945 sha256=f76cd0c1fcdd2e2a3a9dede1f3415f4e883e57fe93a79f5a89f136a7496e5e33
#   Stored in directory: /root/.cache/pip/wheels/c5/4e/2c/251524370c0fdd659e99639a0fbd0ca5a782c3aafcd456b28d
# Successfully built pesq
# Installing collected packages: pesq
# Successfully installed pesq-0.0.4

# %%
# !pip install mir_eval
# Out:
# Collecting mir_eval
#   Downloading mir_eval-0.8.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from mir_eval) (1.26.4)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mir_eval) (1.13.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mir_eval) (4.4.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.15.4->mir_eval) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.15.4->mir_eval) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.15.4->mir_eval) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.15.4->mir_eval) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.15.4->mir_eval) (2024.2.0)
# Downloading mir_eval-0.8.2-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: mir_eval
# Successfully installed mir_eval-0.8.2

# %% [markdown]
# # Step 8: Evaluating the model on STOI, SDR and PESQ

# %%
import os
import torch
import torchaudio
from torchaudio.transforms import Resample
from tqdm import tqdm
from pesq import pesq
from pystoi import stoi
from mir_eval.separation import bss_eval_sources
import numpy as np

# === CONFIG ===
SAMPLE_RATE = 16000
ORIGINAL_PATH = "/kaggle/input/musan-data/musan/speech/us-gov"
RECONSTRUCTED_PATH = "/kaggle/working/reconstructed_usgov_test"

# === EVALUATION METRICS ===
sdr_scores = []
stoi_scores = []
pesq_scores = []

# === FILE LIST ===
reconstructed_files = sorted([
    f for f in os.listdir(RECONSTRUCTED_PATH) if f.endswith("_reconstructed.wav")
])

for rec_file in tqdm(reconstructed_files, desc="🎧 Evaluating"):
    # Match original
    original_name = rec_file.replace("_reconstructed.wav", ".wav")
    orig_path = os.path.join(ORIGINAL_PATH, original_name)
    rec_path = os.path.join(RECONSTRUCTED_PATH, rec_file)

    if not os.path.exists(orig_path):
        print(f"❌ Missing original: {original_name}")
        continue

    # Load both files
    orig_audio, sr1 = torchaudio.load(orig_path)
    rec_audio, sr2 = torchaudio.load(rec_path)

    # Convert to mono
    orig_audio = orig_audio.mean(dim=0)
    rec_audio = rec_audio.mean(dim=0)

    # Resample if needed
    if sr1 != SAMPLE_RATE:
        orig_audio = Resample(sr1, SAMPLE_RATE)(orig_audio)
    if sr2 != SAMPLE_RATE:
        rec_audio = Resample(sr2, SAMPLE_RATE)(rec_audio)

    # Truncate/pad to same length
    min_len = min(orig_audio.shape[-1], rec_audio.shape[-1])
    orig_audio = orig_audio[:min_len]
    rec_audio = rec_audio[:min_len]

    # Convert to numpy
    orig_np = orig_audio.numpy()
    rec_np = rec_audio.numpy()

    # === Metrics ===
    # SDR
    sdr, _, _, _ = bss_eval_sources(orig_np[None], rec_np[None])
    sdr_scores.append(sdr[0])

    # STOI
    stoi_val = stoi(orig_np, rec_np, SAMPLE_RATE, extended=False)
    stoi_scores.append(stoi_val)

    # PESQ
    pesq_val = pesq(SAMPLE_RATE, orig_np, rec_np, 'wb')
    pesq_scores.append(pesq_val)

# === AVERAGES ===
print("\n📊 Evaluation Results on 30 Files:")
print(f"✅ SDR  (Signal-to-Distortion Ratio): {np.mean(sdr_scores):.2f} dB")
print(f"✅ STOI (Speech Intelligibility):     {np.mean(stoi_scores):.3f}")
print(f"✅ PESQ (Perceptual Quality):        {np.mean(pesq_scores):.3f}")
# Out:
# 🎧 Evaluating:   0%|          | 0/30 [00:00<?, ?it/s]<ipython-input-19-870f3a852587>:61: FutureWarning: mir_eval.separation.bss_eval_sources
# 	Deprecated as of mir_eval version 0.8.
# 	It will be removed in mir_eval version 0.9.
#   sdr, _, _, _ = bss_eval_sources(orig_np[None], rec_np[None])
# 🎧 Evaluating: 100%|██████████| 30/30 [00:34<00:00,  1.16s/it]
# 📊 Evaluation Results on 30 Files:
# ✅ SDR  (Signal-to-Distortion Ratio): 6.97 dB
# ✅ STOI (Speech Intelligibility):     0.818
# ✅ PESQ (Perceptual Quality):        1.635
